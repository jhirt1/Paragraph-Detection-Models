# %%
import datetime
import boto3
import botocore
import pandas as pd
import numpy as np
import json
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN, Birch
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import hdbscan

import warnings
warnings.filterwarnings("ignore")

# %%
############################
#     AWS Functions        #
############################

def boto3_session(flavor):
  """
  boto3_session instantiates an AWS session. 
  
  :flavor: indicates if the session should be created at the client or the resouce level
  :return: session
  """

  if flavor == 'client':
    return(boto3.client('s3', 'us-east-2'))
  else:
    return(boto3.resource('s3', 'us-east-2'))


def write_to_s3(sesh, key, obj):
  """
  write_to_s3 will write textract formatted results to the artifact bucket using the provided key.
  
  :sesh: S3 session
  :key: the prefix and key for the object in S3
  """
  
  sesh.Object('uwm-textract-910', key).put(Body=bytes(json.dumps(obj).encode('UTF-8')))
  return

def read_s3_subfiles_src(s3_sesh, prefix):
  """
  read_s3_subfiles gathers all of the object keys from a specific directory in S3.
  
  :session: a boto3 resouce session
  :folder: the directory for inspection
  :return: an array of object keys
  """
  bucket_src = s3_sesh.Bucket('uwm-textract-910')
  files = []
  

  for object_summary in bucket_src.objects.filter(Prefix=prefix):
    if object_summary.key.endswith('.json'):
        files.append(object_summary.key)

    #remove for live automation
    # if len(files) == 1000:
    #     break
  
  return files

def retrieve_s3_subfile (s3_sesh, file):
  
  con_obj = s3_sesh.Object('uwm-textract-910', file)
  file_content = con_obj.get()['Body'].read().decode('utf-8')
  json_content = json.loads(file_content)
  
  return json_content

############################
#       METADATA           #
############################

def append_height_diff_above(json_page):
    for i in range(len(json_page['Blocks']) - 1):
        previous_line = i
        current_line = i + 1
            
        previous_font_size = json_page['Blocks'][previous_line]['BoundingBox']['Height']
        current_t = json_page['Blocks'][current_line]['BoundingBox']['Top']
        previous_t = json_page['Blocks'][previous_line]['BoundingBox']['Top']
        height_diff = current_t - (previous_t + previous_font_size)
        # ive tested with absolute value but do we want the possibility of negative differences?
        json_page['Blocks'][current_line]['height_diff_above'] = abs(height_diff)

    json_page['Blocks'][0]['height_diff_above'] = 0
    return json_page
  
  
def append_height_diff_below(json_page):
    for i in range(len(json_page['Blocks']) - 1):
        previous_line = i
        current_line = i + 1
            
        previous_font_size = json_page['Blocks'][previous_line]['BoundingBox']['Height']
        current_t = json_page['Blocks'][current_line]['BoundingBox']['Top']
        previous_t = json_page['Blocks'][previous_line]['BoundingBox']['Top']
        height_diff = current_t - (previous_t + previous_font_size)
        # ive tested with absolute value but do we want the possibility of negative differences?
        json_page['Blocks'][previous_line]['height_diff_below'] = abs(height_diff)

    json_page['Blocks'][-1]['height_diff_below'] = 0
    return json_page

  
def append_paragraph_number(json_page):
    blocks = json_page['Blocks']
    precision = 2
    p_count = 0
    for i in range(len(json_page['Blocks'])):
        below = round(json_page['Blocks'][i]['height_diff_below'],precision)
        above = round(json_page['Blocks'][i]['height_diff_above'],precision)
        if above > below:
            p_count +=1
        json_page['Blocks'][i]['paragraph'] = p_count
    return json_page

  
def append_paragraph_number_std(json_page):
    blocks = json_page['Blocks']
    data = pd.json_normalize(blocks)
    p_counter = 0 
    p_counts = []
    # remove first observation from calculation since it
    # has a zero in it since first line doesnt have a height above
    height_diff_std = data.height_diff_above.iloc[1::].std()
    height_diff_mean = data.height_diff_above.iloc[1::].mean()
    json_page['height_diff_mean'] = height_diff_mean
    json_page['height_diff_std'] = height_diff_std
    
    for i in range(len(json_page['Blocks'])):
        if json_page['Blocks'][i]['height_diff_above'] > (height_diff_mean+height_diff_std):
            p_counter+=1
        json_page['Blocks'][i]['paragraph_std'] = p_counter
    return json_page
      
      
def append_scaled(json_page):
    blocks = json_page['Blocks']
    data = pd.json_normalize(blocks)
    feats = ['BoundingBox.Top', 'BoundingBox.Left', 'paragraph_std', 'paragraph']
    X = data[feats]
    
    scaler = MinMaxScaler()
    X_scl = scaler.fit_transform(X)
    dim1 = X_scl.shape[0]
    dim2 = X_scl.shape[-1]
    for i in range(dim1):
        for j in range(dim2):
            if j==0:
                json_page['Blocks'][i]['top_scl'] = X_scl[i][j]
            if j == 1:
                json_page['Blocks'][i]['left_scl'] = X_scl[i][j]
            elif j == 2:
                json_page['Blocks'][i]['paragraph_std_scl'] = X_scl[i][j]
            else:
                json_page['Blocks'][i]['paragraph_scl'] = X_scl[i][j]
    return json_page
        

def append_cluster(json_page, pca=True):
    blocks = json_page['Blocks']
    feats = ['top_scl', 'left_scl', 'paragraph_std_scl']
    X_scl = pd.json_normalize(blocks)[feats]

    if pca:
        pca = PCA(n_components=2)
        pca_out = pca.fit_transform(X_scl)

        clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
        clusterer.fit(pca_out)
        hdbscan_labels = clusterer.labels_
        cluster_probs = clusterer.probabilities_
    else:
        clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
        clusterer.fit(pca_out)
        hdbscan_labels = clusterer.labels_
        cluster_probs = clusterer.probabilities_


    for i in range(len(json_page['Blocks'])):
        json_page['Blocks'][i]['text_cluster'] = int(hdbscan_labels[i])
        json_page['Blocks'][i]['cluster_probability'] = float(cluster_probs[i])

    return json_page

# %%
############################
#       MAIN               #
############################

def main():
    file_arr = []

    s3_sesh = boto3_session('resource')
    target = f'Textract_Output'
  
    #for target in targets
    #gather the files paths from S3
    files = read_s3_subfiles_src(s3_sesh, target)
    files = [files[0]]
    
    #gather the file contents 
    for idx, file in enumerate(files):

      page = retrieve_s3_subfile(s3_sesh, file)
      file_name = file.split('/')[-1].split('.')[0]+'.pdf'
      dest_name = file.split('/')[-1]
      dest = f'T2_Model/{dest_name}'

      #calculate quadrant borders
      df = pd.DataFrame(page)
      df = df.join(pd.json_normalize(df["Blocks"].tolist()).add_prefix("Blocks.")).drop(["Blocks"], axis=1)
      
      #vertical
      top = df['Blocks.BoundingBox.Top'].min()
      df['Blocks.BoundingBox.Bottom'] = df['Blocks.BoundingBox.Top'] + df['Blocks.BoundingBox.Height']
      bottom = df['Blocks.BoundingBox.Bottom'].max()
      v_midpoint = (bottom-top)/2

      #horizontal
      left = df['Blocks.BoundingBox.Left'].min()
      df['Blocks.BoundingBox.Right'] = df['Blocks.BoundingBox.Left'] + df['Blocks.BoundingBox.Width']
      right = df['Blocks.BoundingBox.Right'].max()
      h_midpoint = (right-left)/2

      #assign quadrants
      for idx, block in enumerate(page['Blocks']):
        if block['BoundingBox']['Top'] < v_midpoint and block['BoundingBox']['Left'] < h_midpoint:
            block['Quadrant'] = 'Q1'
        elif block['BoundingBox']['Top'] < v_midpoint and block['BoundingBox']['Left'] > h_midpoint:
            block['Quadrant'] = 'Q2'
        elif block['BoundingBox']['Top'] > v_midpoint and block['BoundingBox']['Left'] < h_midpoint:
            block['Quadrant'] = 'Q3'
        elif block['BoundingBox']['Top'] > v_midpoint and block['BoundingBox']['Left'] > h_midpoint:
            block['Quadrant'] = 'Q4'

      #parition quadrants
      core = page['Blocks']
      core_q1 = {'Blocks':[x for x in core if x['Quadrant'] in ['Q1']]}
      core_q2 = {'Blocks':[x for x in core if x['Quadrant'] in ['Q2']]}
      core_q3 = {'Blocks':[x for x in core if x['Quadrant'] in ['Q3']]}
      core_q4 = {'Blocks':[x for x in core if x['Quadrant'] in ['Q4']]}

      core_full = [core_q1, core_q2, core_q3, core_q4]

      
      final_blocks = []
      for quad in core_full:
        if len(quad['Blocks']) > 1:
            height_diff_above_json = append_height_diff_above(quad)
            height_diff_below_json = append_height_diff_below(height_diff_above_json)
            paragraph_number_json = append_paragraph_number(height_diff_below_json)
            pg_num_std_json = append_paragraph_number_std(paragraph_number_json)
            scaled_json = append_scaled(pg_num_std_json)
            clustered_json = append_cluster(scaled_json)
            final_blocks.extend(clustered_json['Blocks'])
    


      final_json = {
        'Page': 1,
        'Blocks': final_blocks,
        'file_name': file_name
      }
      
      write_to_s3(s3_sesh, dest, final_json)
      file_arr.append(dest)

    return final_json

# %%
file_arr = main()
file_arr
# Out:
# {'Page': 1,
#  'Blocks': [{'BlockType': 'LINE',
#    'Confidnece': 99.89444732666016,
#    'Text': '16',
#    'BoundingBox': {'Width': 0.01270796824246645,
#     'Height': 0.00822802446782589,
#     'Left': 0.14141608774662018,
#     'Top': 0.0827944353222847},
#    'Id': '371f4a21-2453-4350-878b-30087aca9773',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0,
#    'height_diff_below': 0.048604803159832954,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.06640953197713628,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8537826538086,
#    'Text': 'statement to the subject field of knowledge organiza-',
#    'BoundingBox': {'Width': 0.33351844549179077,
#     'Height': 0.012791251763701439,
#     'Left': 0.14064253866672516,
#     'Top': 0.13962726294994354},
#    'Id': 'bfe1faf7-b5c9-461e-bbae-7e3ca74dd8da',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.048604803159832954,
#    'height_diff_below': 0.002115631476044655,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.18505209484783108,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.021211870567800162,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.605712890625,
#    'Text': 'tion. In a much sharper form, Rudolf Wohl-genannt',
#    'BoundingBox': {'Width': 0.33333906531333923,
#     'Height': 0.012794182635843754,
#     'Left': 0.14088498055934906,
#     'Top': 0.15453414618968964},
#    'Id': '17732c2a-bb28-470d-befa-0e008888f4a5',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.002115631476044655,
#    'height_diff_below': 0.0015471568331122398,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.23359006289052148,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.035377496071150816,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.16608428955078,
#    'Text': '(1969) formulated his criteria, also basing his argu-',
#    'BoundingBox': {'Width': 0.3323722183704376,
#     'Height': 0.013211066834628582,
#     'Left': 0.14186304807662964,
#     'Top': 0.16887548565864563},
#    'Id': 'b6990175-a9d9-4bbe-ae30-38d8e5c774e6',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0015471568331122398,
#    'height_diff_below': 0.0018965797498822212,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.2802865765505706,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.09252495526988191,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.777587890625,
#    'Text': 'ments on the propositional concept of science. How-',
#    'BoundingBox': {'Width': 0.3334891200065613,
#     'Height': 0.012704968452453613,
#     'Left': 0.1408361941576004,
#     'Top': 0.18398313224315643},
#    'Id': '053ed733-a87a-47d1-bfcf-d5902a7287db',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0018965797498822212,
#    'height_diff_below': 0.0015482306480407715,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.3294782456155077,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.03252695778608761,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 2,
#    'cluster_probability': 0.6091304911248301},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.7857894897461,
#    'Text': 'ever, neither space nor time permits further elabora-',
#    'BoundingBox': {'Width': 0.33318468928337097,
#     'Height': 0.013134063221514225,
#     'Left': 0.14063189923763275,
#     'Top': 0.19823633134365082},
#    'Id': '112dab44-96c6-499a-b856-88c685af0cc3',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0015482306480407715,
#    'height_diff_below': 0.0017581870779395103,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.37588776739946467,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.020590219884985217,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92301177978516,
#    'Text': 'tion on these criteria here. But they should be con-',
#    'BoundingBox': {'Width': 0.33350473642349243,
#     'Height': 0.012872094288468361,
#     'Left': 0.14092649519443512,
#     'Top': 0.21312858164310455},
#    'Id': '07ed5518-71c5-48b6-8426-577ec033c544',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0017581870779395103,
#    'height_diff_below': 0.0017576422542333603,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.42437808945359673,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.037803152657033934,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92363739013672,
#    'Text': 'sidered if further clarification of this matter is sought.',
#    'BoundingBox': {'Width': 0.33303913474082947,
#     'Height': 0.012774121016263962,
#     'Left': 0.14059630036354065,
#     'Top': 0.22775831818580627},
#    'Id': '8ac86447-1a56-40d7-8e6a-1719598dd52a',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0017576422542333603,
#    'height_diff_below': 0.002036426216363907,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.47201364635453963,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.01851021500929484,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92655181884766,
#    'Text': 'Another essential aspect of science at large is that',
#    'BoundingBox': {'Width': 0.31676965951919556,
#     'Height': 0.012812000699341297,
#     'Left': 0.15739430487155914,
#     'Top': 0.24256886541843414},
#    'Id': '6176890c-f9b7-4c7d-9abc-c56b5a45d8a2',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.002036426216363907,
#    'height_diff_below': 0.0021168915554881096,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.5202379368859984,
#    'paragraph_scl': 1.0,
#    'left_scl': 1.0,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78694915771484,
#    'Text': 'it affords theories, models, and hypotheses to',
#    'BoundingBox': {'Width': 0.3338502049446106,
#     'Height': 0.012599295005202293,
#     'Left': 0.14034253358840942,
#     'Top': 0.25749775767326355},
#    'Id': '1709e05f-365e-43c0-a4a0-5607736b7381',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0021168915554881096,
#    'height_diff_below': 0.002031410112977028,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.5688475679888727,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.0036828884990267596,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 0.7321083520863201},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90020751953125,
#    'Text': 'emerge. In this respect, I should like to point out that',
#    'BoundingBox': {'Width': 0.3335620164871216,
#     'Height': 0.012744327075779438,
#     'Left': 0.14081494510173798,
#     'Top': 0.27212846279144287},
#    'Id': '9245d182-7c2c-4780-81e8-69368a44b5e7',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.002031410112977028,
#    'height_diff_below': 0.002109716646373272,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.6164862786466956,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.03128539773889827,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.9135513305664,
#    'Text': 'the whole lot of more or less intuitively conceived',
#    'BoundingBox': {'Width': 0.33300063014030457,
#     'Height': 0.012546517886221409,
#     'Left': 0.1408093273639679,
#     'Top': 0.2869825065135956},
#    'Id': 'f9376a3d-526d-48a1-bd47-f3769e5b214e',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.002109716646373272,
#    'height_diff_below': 0.001976064406335354,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.6648521971217407,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.030957159213098606,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88229370117188,
#    'Text': 'universal and special classification systems, from the',
#    'BoundingBox': {'Width': 0.3339512050151825,
#     'Height': 0.012628613971173763,
#     'Left': 0.14054933190345764,
#     'Top': 0.30150508880615234},
#    'Id': 'e195b32b-fa14-473f-bed2-818932d7e78d',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.001976064406335354,
#    'height_diff_below': 0.0015401849523186684,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.7121388514730675,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.015765897149027097,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.71378326416016,
#    'Text': 'beginning of mankind until down to the whole 19th',
#    'BoundingBox': {'Width': 0.33433082699775696,
#     'Height': 0.013225675560534,
#     'Left': 0.14039158821105957,
#     'Top': 0.3156738877296448},
#    'Id': '94b8b958-d124-45f9-a5c4-c7f637fe3489',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0015401849523186684,
#    'height_diff_below': 0.0020563891157507896,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.7582735597344235,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.006549098650042495,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8968734741211,
#    'Text': 'century, were not at all based on theoretical consid-',
#    'BoundingBox': {'Width': 0.33353304862976074,
#     'Height': 0.012469153851270676,
#     'Left': 0.1407458782196045,
#     'Top': 0.33095595240592957},
#    'Id': '3fb255cc-dea2-431c-b4e4-39f4ec9e821b',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0020563891157507896,
#    'height_diff_below': 0.0023206062614917755,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.8080331476344675,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.027249892255921893,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.76758575439453,
#    'Text': 'erations. Similarly, all efforts in the past centuries to-',
#    'BoundingBox': {'Width': 0.3338283598423004,
#     'Height': 0.012700652703642845,
#     'Left': 0.14065471291542053,
#     'Top': 0.345745712518692},
#    'Id': 'df71d3f9-fb94-4c29-ad16-0cbbca317fb1',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0023206062614917755,
#    'height_diff_below': 0.0021241549402475357,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.856189753691345,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.021923199150236883,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91869354248047,
#    'Text': 'wards systematizing knowledge on the part of phi-',
#    'BoundingBox': {'Width': 0.3333619236946106,
#     'Height': 0.012726237066090107,
#     'Left': 0.14096924662590027,
#     'Top': 0.3605705201625824},
#    'Id': '546fd4c6-1ade-439c-b650-25e50f00c0a9',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0021241549402475357,
#    'height_diff_below': 0.001963595859706402,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.9044604772279465,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.040301073958147526,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86183166503906,
#    'Text': 'losophers were not useful for our purposes by the',
#    'BoundingBox': {'Width': 0.3341689705848694,
#     'Height': 0.012732046656310558,
#     'Left': 0.14027950167655945,
#     'Top': 0.3752603530883789},
#    'Id': 'f0954340-fd8e-4a19-b9dc-622969df8af2',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.001963595859706402,
#    'height_diff_below': 0.0019200267270207405,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.9522917126134676,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.0,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.95042419433594,
#    'Text': 'simple fact that systems were developed always only',
#    'BoundingBox': {'Width': 0.3338403105735779,
#     'Height': 0.012876993976533413,
#     'Left': 0.14079207181930542,
#     'Top': 0.3899124264717102},
#    'Id': '595aeb87-f405-401d-96b8-4b1a0488842f',
#    'Quadrant': 'Q1',
#    'height_diff_above': 0.0019200267270207405,
#    'height_diff_below': 0,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.9999999999999998,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.029948935836769053,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 0,
#    'cluster_probability': 0.7285447949489072},
#   {'BlockType': 'LINE',
#    'Confidnece': 83.62879180908203,
#    'Text': 'Knowl. Org. (2006)M',
#    'BoundingBox': {'Width': 0.13195845484733582,
#     'Height': 0.01113848015666008,
#     'Left': 0.7039221525192261,
#     'Top': 0.0818491131067276},
#    'Id': 'feca5336-ce09-4ee5-8872-5dd92ac10bf0',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0,
#    'height_diff_below': 0.001437503844499588,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.9999999999999996,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.06912994384766,
#    'Text': 'Ingetraut Dahlberg. Knowledge Organization: A New Science?',
#    'BoundingBox': {'Width': 0.3566962480545044,
#     'Height': 0.011461430229246616,
#     'Left': 0.5014880299568176,
#     'Top': 0.09442509710788727},
#    'Id': 'fe68a6da-9331-482e-a236-72a3d76250ff',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.001437503844499588,
#    'height_diff_below': 0.033809117041528225,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.04078720523987711,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8111343383789,
#    'Text': 'regarding their functional relations. By applying this',
#    'BoundingBox': {'Width': 0.3333342969417572,
#     'Height': 0.012892329134047031,
#     'Left': 0.5251580476760864,
#     'Top': 0.1396956443786621},
#    'Id': 'bee52242-04a2-4b9b-894c-4fa39743ee20',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.033809117041528225,
#    'height_diff_below': 0.0019321655854582787,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.1876114301024711,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.11692701516747261,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 0.49830892040208397},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.94509887695312,
#    'Text': 'knowledge to the construction and utilization of',
#    'BoundingBox': {'Width': 0.33475708961486816,
#     'Height': 0.012536060996353626,
#     'Left': 0.5250515937805176,
#     'Top': 0.15452013909816742},
#    'Id': 'dfde7ba2-57e4-430e-8b13-8ba387de2a8c',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0019321655854582787,
#    'height_diff_below': 0.002177300862967968,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.23569114367766186,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.11640114584158345,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 0.9923274253033202},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.79900360107422,
#    'Text': 'concept as well as classification systems and thesauri,',
#    'BoundingBox': {'Width': 0.33345913887023926,
#     'Height': 0.012515096925199032,
#     'Left': 0.5251613855361938,
#     'Top': 0.169233500957489},
#    'Id': '31f77913-a7fe-44ca-adfa-53f464787839',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.002177300862967968,
#    'height_diff_below': 0.0019212374463677406,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.28341042432157737,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.11694350379135265,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.94812774658203,
#    'Text': 'the field of knowledge organization has developed',
#    'BoundingBox': {'Width': 0.33369678258895874,
#     'Height': 0.013027486391365528,
#     'Left': 0.5249930024147034,
#     'Top': 0.1836698353290558},
#    'Id': 'de2e0c24-8839-4c2c-ae66-87405f60c0ce',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0019212374463677406,
#    'height_diff_below': 0.0016938475891947746,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.33023123236890706,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.11611171160454603,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8287353515625,
#    'Text': 'from a more or less intuitive art into a new and a',
#    'BoundingBox': {'Width': 0.3339478671550751,
#     'Height': 0.00999689195305109,
#     'Left': 0.5250462293624878,
#     'Top': 0.1983911693096161},
#    'Id': '3bb92a07-b243-4bf1-a970-0c449af84e33',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0016938475891947746,
#    'height_diff_below': 0.004919453524053097,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.3779763686870291,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.11637464626749061,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 0.9870318042747905},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.37953186035156,
#    'Text': 'truly scientific discipline.',
#    'BoundingBox': {'Width': 0.1573156863451004,
#     'Height': 0.01281749177724123,
#     'Left': 0.5252102613449097,
#     'Top': 0.21330751478672028},
#    'Id': 'f573ff9f-b72b-4b37-b336-b404ad7997d6',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.004919453524053097,
#    'height_diff_below': 0.016646320931613445,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.42635397829176924,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.1171849443553108,
#    'paragraph_std_scl': 0.3333333333333333,
#    'text_cluster': 0,
#    'cluster_probability': 0.4967562108057693},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.9332504272461,
#    'Text': '6. Knowledge Organization in the Universal',
#    'BoundingBox': {'Width': 0.29224711656570435,
#     'Height': 0.012664775364100933,
#     'Left': 0.5251368284225464,
#     'Top': 0.24277132749557495},
#    'Id': 'effeeb6d-3f32-46a2-a16f-e1b2bb6eef8f',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.016646320931613445,
#    'height_diff_below': 0.002087523229420185,
#    'paragraph': 2,
#    'paragraph_std': 2,
#    'top_scl': 0.5219128288751144,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.11682219462994947,
#    'paragraph_std_scl': 0.6666666666666666,
#    'text_cluster': 0,
#    'cluster_probability': 0.09540696513269963},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92008972167969,
#    'Text': 'Context of Knowledge Fields',
#    'BoundingBox': {'Width': 0.19159768521785736,
#     'Height': 0.012635654769837856,
#     'Left': 0.5422691106796265,
#     'Top': 0.25752362608909607},
#    'Id': '7cadac90-fa85-465c-97ff-a3821a695509',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.002087523229420185,
#    'height_diff_below': 0.016745352186262608,
#    'paragraph': 2,
#    'paragraph_std': 2,
#    'top_scl': 0.5697583915315563,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.201453589970912,
#    'paragraph_std_scl': 0.6666666666666666,
#    'text_cluster': 0,
#    'cluster_probability': 0.09237366212008495},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.863525390625,
#    'Text': 'If knowledge organization can be regarded as a new',
#    'BoundingBox': {'Width': 0.33396947383880615,
#     'Height': 0.01274898648262024,
#     'Left': 0.5249465703964233,
#     'Top': 0.28690463304519653},
#    'Id': 'cbb00a9c-6371-4efb-8a43-91259a4e685d',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.016745352186262608,
#    'height_diff_below': 0.001918882131576538,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.6650486814016946,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11588234306878586,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.5063165746669006},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.43020629882812,
#    'Text': 'scientific discipline, into which environment would',
#    'BoundingBox': {'Width': 0.333626925945282,
#     'Height': 0.012481371872127056,
#     'Left': 0.5253270864486694,
#     'Top': 0.3015725016593933},
#    'Id': '5263ba47-6d65-4058-8766-82a43086a110',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.001918882131576538,
#    'height_diff_below': 0.002353866584599018,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.7126204155533624,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11776204619111308,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91425323486328,
#    'Text': 'it come? Would it belong into the environment of',
#    'BoundingBox': {'Width': 0.334908664226532,
#     'Height': 0.012520850636065006,
#     'Left': 0.5249782204627991,
#     'Top': 0.3164077401161194},
#    'Id': '5c28901f-0b18-4de5-bb59-13ab8198d222',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.002353866584599018,
#    'height_diff_below': 0.0020238151773810387,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.7607349738782782,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.1160386905559343,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89966583251953,
#    'Text': 'the information sciences? In our Information Coding',
#    'BoundingBox': {'Width': 0.3339965343475342,
#     'Height': 0.012581463903188705,
#     'Left': 0.5251020789146423,
#     'Top': 0.33095240592956543},
#    'Id': 'd6d2c223-45b5-42af-8744-6e36db03ef66',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0020238151773810387,
#    'height_diff_below': 0.0023473240435123444,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.8079071291246386,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11665053627776967,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.62623596191406,
#    'Text': 'Classification (Dahlberg 1982) we postulated nine',
#    'BoundingBox': {'Width': 0.33312031626701355,
#     'Height': 0.012629813514649868,
#     'Left': 0.5255029201507568,
#     'Top': 0.3458811938762665},
#    'Id': '10e2d464-cb4f-4006-aaea-2873ab0ff8f7',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0023473240435123444,
#    'height_diff_below': 0.002173357643187046,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.856325092912486,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11863064334193751,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92660522460938,
#    'Text': 'ontical areas by starting from the objects of reality,',
#    'BoundingBox': {'Width': 0.33262187242507935,
#     'Height': 0.012568943202495575,
#     'Left': 0.5256136655807495,
#     'Top': 0.3606843650341034},
#    'Id': 'fe882db8-f879-4535-aa5a-0af31f5688ba',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.002173357643187046,
#    'height_diff_below': 0.0019180849194526672,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.9043356486002198,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11917771232710095,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.95030212402344,
#    'Text': 'which in the sense of the theory of integrative levels',
#    'BoundingBox': {'Width': 0.3335983455181122,
#     'Height': 0.012633396312594414,
#     'Left': 0.5249602198600769,
#     'Top': 0.37517139315605164},
#    'Id': '1575e0e4-5ca0-4ddc-ad1f-b51101e4f16e',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0019180849194526672,
#    'height_diff_below': 0.0023759175091981888,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 0.9513208697384851,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11594976976286686,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.9951820985340217},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.7477035522461,
#    'Text': 'according to J.K.Feibleman (1954) and Nicolai',
#    'BoundingBox': {'Width': 0.3334772288799286,
#     'Height': 0.012533879838883877,
#     'Left': 0.5252562761306763,
#     'Top': 0.39018070697784424},
#    'Id': 'f299f174-8e21-460f-8f33-8d598fa5504a',
#    'Quadrant': 'Q2',
#    'height_diff_above': 0.0023759175091981888,
#    'height_diff_below': 0,
#    'paragraph': 3,
#    'paragraph_std': 3,
#    'top_scl': 1.0,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.11741225181308579,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.5058453414506059},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88802337646484,
#    'Text': 'deductively by disciplines although subjects were or-',
#    'BoundingBox': {'Width': 0.33366909623146057,
#     'Height': 0.012750514782965183,
#     'Left': 0.14048489928245544,
#     'Top': 0.40458616614341736},
#    'Id': 'd7ad57d2-6488-4bbb-8d38-068c031cddb3',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0,
#    'height_diff_below': 0.00204452034085989,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.07516500539061433,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91565704345703,
#    'Text': 'ganized based on best personal knowledge and good',
#    'BoundingBox': {'Width': 0.3339214622974396,
#     'Height': 0.012898399494588375,
#     'Left': 0.14062906801700592,
#     'Top': 0.41938120126724243},
#    'Id': 'b08c3698-3483-4466-abee-d5ae032f037c',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.00204452034085989,
#    'height_diff_below': 0.0015851715579628944,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.031389164267192404,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.08287442059860162,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.73370361328125,
#    'Text': 'will. But exactly that knowledge, which manifests it-',
#    'BoundingBox': {'Width': 0.3338701128959656,
#     'Height': 0.01276412419974804,
#     'Left': 0.14057786762714386,
#     'Top': 0.4338647723197937},
#    'Id': '10593bfd-74ad-4ea1-9562-d88588edcd6a',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0015851715579628944,
#    'height_diff_below': 0.001967819407582283,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.06211752598713027,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.08013648254644234,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 98.34413146972656,
#    'Text': 'self in single concepts and statements - the inductive',
#    'BoundingBox': {'Width': 0.33412447571754456,
#     'Height': 0.013056878000497818,
#     'Left': 0.14048580825328827,
#     'Top': 0.448596715927124},
#    'Id': 'd7da6644-1b84-42b1-84ae-5dfb469b507b',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.001967819407582283,
#    'height_diff_below': 0.0018566213548183441,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.09337283521724127,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0752136125562668,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 98.75491333007812,
#    'Text': 'way - did not carry. Nor did the third approach carry,',
#    'BoundingBox': {'Width': 0.333779513835907,
#     'Height': 0.012895893305540085,
#     'Left': 0.1405445635318756,
#     'Top': 0.4635102152824402},
#    'Id': '1525b6ef-7c1c-429d-a5a8-de5bb4a42b65',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0018566213548183441,
#    'height_diff_below': 0.0015765614807605743,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.1250133333400777,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0783555478704887,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88494110107422,
#    'Text': 'the necessary use of formal relationships, originating',
#    'BoundingBox': {'Width': 0.3338810205459595,
#     'Height': 0.013124711811542511,
#     'Left': 0.14087365567684174,
#     'Top': 0.47798267006874084},
#    'Id': '139766be-a5ac-4707-bf5d-5dc61721efe2',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0015765614807605743,
#    'height_diff_below': 0.00184737890958786,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.155718110776203,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.09595373235300908,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.818359375,
#    'Text': 'from different concept categories. Starting from the',
#    'BoundingBox': {'Width': 0.33393770456314087,
#     'Height': 0.012900739908218384,
#     'Left': 0.14071696996688843,
#     'Top': 0.4929547607898712},
#    'Id': '35cafacd-dabb-421c-8dce-1220ac50863b',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.00184737890958786,
#    'height_diff_below': 0.0016592144966125488,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.18748291641103842,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.08757497256882552,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93363952636719,
#    'Text': 'approach that had guided Bliss in his time, the Indian',
#    'BoundingBox': {'Width': 0.33405983448028564,
#     'Height': 0.012823207303881645,
#     'Left': 0.14038687944412231,
#     'Top': 0.5075147151947021},
#    'Id': '28e6bc24-3bcc-45bf-b656-7ca0479b1d5d',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0016592144966125488,
#    'height_diff_below': 0.0019294191151857376,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.21837333314280427,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0699233998879647,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87799835205078,
#    'Text': 'mathematician and later librarian of the University',
#    'BoundingBox': {'Width': 0.33449897170066833,
#     'Height': 0.012419668957591057,
#     'Left': 0.14029066264629364,
#     'Top': 0.5222673416137695},
#    'Id': '52cee6c0-7e15-4224-b8a2-2ce2ddc4832f',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0019294191151857376,
#    'height_diff_below': 0.0021869856864213943,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.2496725230511082,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.06477821187783839,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.49018096923828,
#    'Text': 'Library of Madras, S.R. Ranganathan, developed a',
#    'BoundingBox': {'Width': 0.33403462171554565,
#     'Height': 0.012710361741483212,
#     'Left': 0.14080236852169037,
#     'Top': 0.536873996257782},
#    'Id': '0e330317-7416-4f6f-9e3f-92f04b09b6d7',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0021869856864213943,
#    'height_diff_below': 0.002163202501833439,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.28066201906634436,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.09214165562380927,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87751007080078,
#    'Text': 'new paradigm of classification theory for the entire',
#    'BoundingBox': {'Width': 0.3338565230369568,
#     'Height': 0.01276537124067545,
#     'Left': 0.14072899520397186,
#     'Top': 0.5517475605010986},
#    'Id': '28dc042f-0d0a-47c7-b9ef-1bdfc0c1f3bd',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002163202501833439,
#    'height_diff_below': 0.0021105771884322166,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.31221779080765544,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.08821802146524327,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91859436035156,
#    'Text': 'period following with his faceted classification sys-',
#    'BoundingBox': {'Width': 0.33401060104370117,
#     'Height': 0.012574324384331703,
#     'Left': 0.1404758095741272,
#     'Top': 0.5666235089302063},
#    'Id': '4683d348-85c4-478a-b5b3-e0371ce89fee',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0021105771884322166,
#    'height_diff_below': 0.0021442677825689316,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.3437786208404009,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.07467893373409051,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 94.0677719116211,
#    'Text': 'tem, which allows all concept combinations possible.',
#    'BoundingBox': {'Width': 0.3336128294467926,
#     'Height': 0.012695197947323322,
#     'Left': 0.1406274139881134,
#     'Top': 0.5813421010971069},
#    'Id': 'a805fa25-5598-4b6e-8f65-ecdf4a2c6110',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0021442677825689316,
#    'height_diff_below': 0.002126808278262615,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.37500560363847957,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.08278597149388922,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.45995330810547,
#    'Text': 'He explained it in his Prolegomena (1937).',
#    'BoundingBox': {'Width': 0.2612755000591278,
#     'Height': 0.01255890168249607,
#     'Left': 0.14060287177562714,
#     'Top': 0.5961641073226929},
#    'Id': '7142ac0b-8ff4-4b37-b196-327d0d140bb5',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002126808278262615,
#    'height_diff_below': 0.0018561240285634995,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.40645198982752306,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0814735780212743,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93061065673828,
#    'Text': 'Therefore, one may conclude that the field of',
#    'BoundingBox': {'Width': 0.3184407651424408,
#     'Height': 0.012782597914338112,
#     'Left': 0.15694592893123627,
#     'Top': 0.6105791330337524},
#    'Id': '4eed7288-187c-4dec-9dbb-b794f7001d57',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0018561240285634995,
#    'height_diff_below': 0.002265429124236107,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.4370349256687235,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.9554176670313534,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 0,
#    'cluster_probability': 0.055255419309784774},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.67272186279297,
#    'Text': '"Knowledge Organization" obeys the science criteria',
#    'BoundingBox': {'Width': 0.33330971002578735,
#     'Height': 0.013038299977779388,
#     'Left': 0.14111372828483582,
#     'Top': 0.6256271600723267},
#    'Id': '845a783b-d3ab-411c-a635-b2462cf31c4a',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002265429124236107,
#    'height_diff_below': 0.001369871199131012,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.46896083788574294,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.10879160195671744,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88046264648438,
#    'Text': 'formulated by Diemer, and that it received in the',
#    'BoundingBox': {'Width': 0.33356717228889465,
#     'Height': 0.012571873143315315,
#     'Left': 0.14045962691307068,
#     'Top': 0.6400353312492371},
#    'Id': 'dd264d6c-a4bb-4247-8b33-63954cec181f',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.001369871199131012,
#    'height_diff_below': 0.002090631052851677,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.49952923113906966,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.07381356681772111,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.76185607910156,
#    'Text': 'past century also the necessary theoretical founda-',
#    'BoundingBox': {'Width': 0.3319475054740906,
#     'Height': 0.012959086336195469,
#     'Left': 0.14034156501293182,
#     'Top': 0.654697835445404},
#    'Id': 'afd420e7-9163-4852-8ca8-ad496b420bd8',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002090631052851677,
#    'height_diff_below': 0.002340412698686123,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.5306372176311552,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.06750021315437404,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 94.87834930419922,
#    'Text': 'tion - especially by:',
#    'BoundingBox': {'Width': 0.12345987558364868,
#     'Height': 0.012443149462342262,
#     'Left': 0.14097051322460175,
#     'Top': 0.6699973344802856},
#    'Id': '04f1d778-90f4-4d09-9ca0-7cd8f955a39f',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002340412698686123,
#    'height_diff_below': 0.016703223809599876,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.5630966531372125,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.10113318443072661,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 0.9888513959709215},
#   {'BlockType': 'LINE',
#    'Confidnece': 97.39653015136719,
#    'Text': '- The work of Ranganathan, regarding categoriza-',
#    'BoundingBox': {'Width': 0.33416563272476196,
#     'Height': 0.01276026014238596,
#     'Left': 0.1399727612733841,
#     'Top': 0.6991437077522278},
#    'Id': 'e282fa06-8f92-4067-9583-ae3a598a8ee6',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.016703223809599876,
#    'height_diff_below': 0.0016477322205901146,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.6249336336356653,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.047778453319988756,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 2,
#    'cluster_probability': 0.1167755542582012},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.70093536376953,
#    'Text': 'tion (facet analysis) and ruled concept combina-',
#    'BoundingBox': {'Width': 0.3161333203315735,
#     'Height': 0.012904278934001923,
#     'Left': 0.15762679278850555,
#     'Top': 0.7135517001152039},
#    'Id': 'c599088b-b5c6-4b27-95f8-9e245a860cc1',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0016477322205901146,
#    'height_diff_below': 0.001894541084766388,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.6555016475171346,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.9918268246213628,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 0.7631259698721233},
#   {'BlockType': 'LINE',
#    'Confidnece': 98.415771484375,
#    'Text': 'tions - partly already anticipated by the invention',
#    'BoundingBox': {'Width': 0.3162139058113098,
#     'Height': 0.013149050995707512,
#     'Left': 0.15777963399887085,
#     'Top': 0.7283505201339722},
#    'Id': 'fa1cd9df-2c5f-449a-8225-ea2e72a5a566',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.001894541084766388,
#    'height_diff_below': 0.0013860780745744705,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.6868988418219789,
#    'paragraph_scl': 0.5,
#    'left_scl': 1.0,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6538314819336,
#    'Text': 'of auxiliaries through Otlet and LaFontaine in re-',
#    'BoundingBox': {'Width': 0.3165777325630188,
#     'Height': 0.012752125039696693,
#     'Left': 0.15763069689273834,
#     'Top': 0.7428856492042542},
#    'Id': '174545f9-d69f-482f-a785-c4a24ba4e249',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0013860780745744705,
#    'height_diff_below': 0.002248873934149742,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.7177365890941846,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.9920355963820331,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.36225128173828,
#    'Text': 'vising and enlarging the Dewey Decimal Classifi-',
#    'BoundingBox': {'Width': 0.3163096308708191,
#     'Height': 0.01273859292268753,
#     'Left': 0.15716272592544556,
#     'Top': 0.7578866481781006},
#    'Id': '66bc676e-dd4b-419d-8d82-c0c2e6e41dbb',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002248873934149742,
#    'height_diff_below': 0.0021350905299186707,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.7495627265126615,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.9670108744588468,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.43053436279297,
#    'Text': 'cation; and,',
#    'BoundingBox': {'Width': 0.07156182825565338,
#     'Height': 0.011422564275562763,
#     'Left': 0.15709029138088226,
#     'Top': 0.7727603316307068},
#    'Id': '28bf5f40-b1a6-4f44-88f7-ac3c841f2355',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0021350905299186707,
#    'height_diff_below': 0.0029941899701952934,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.7811187511685443,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.9631374411434965,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 0.6468919556548158},
#   {'BlockType': 'LINE',
#    'Confidnece': 97.80340576171875,
#    'Text': '- The work of Wüster regarding system formation',
#    'BoundingBox': {'Width': 0.3344232738018036,
#     'Height': 0.012835073284804821,
#     'Left': 0.13988789916038513,
#     'Top': 0.7871770858764648},
#    'Id': '7dba55a3-9b6f-4d7d-89e8-2903c97237b6',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0029941899701952934,
#    'height_diff_below': 0.0020530940964818,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.8117053542710347,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.04324045646112751,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 2,
#    'cluster_probability': 0.10852349065210613},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88549041748047,
#    'Text': 'on the basis of the two hierarchical forms of con-',
#    'BoundingBox': {'Width': 0.31638944149017334,
#     'Height': 0.010151571594178677,
#     'Left': 0.1576206088066101,
#     'Top': 0.8020652532577515},
#    'Id': 'bfd6a49c-22d1-4a0a-a50d-1f7a605c4934',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0020530940964818,
#    'height_diff_below': 0.0044526392593979836,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.8432921080473813,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.9914961365271697,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 0.5901924519503198},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86510467529297,
#    'Text': 'cept systems using the Logic of Port Royal.',
#    'BoundingBox': {'Width': 0.2720799744129181,
#     'Height': 0.012662168592214584,
#     'Left': 0.15776361525058746,
#     'Top': 0.8166694641113281},
#    'Id': '7a77a7fc-5958-4a40-9a89-98d29beeca28',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0044526392593979836,
#    'height_diff_below': 0.01698559895157814,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.8742764193138971,
#    'paragraph_scl': 0.5,
#    'left_scl': 0.999143398310224,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 0.41543100541556227},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78136444091797,
#    'Text': 'Further, researchers such as E. de Grolier (1962) and',
#    'BoundingBox': {'Width': 0.33425086736679077,
#     'Height': 0.012359503656625748,
#     'Left': 0.14039255678653717,
#     'Top': 0.8463172316551208},
#    'Id': '26ac3393-03b6-46d8-9b2b-86b08ee7a8e6',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.01698559895157814,
#    'height_diff_below': 0.002234991639852524,
#    'paragraph': 2,
#    'paragraph_std': 2,
#    'top_scl': 0.937177158500993,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.07022699546359679,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.76679992675781,
#    'Text': 'J. Perreault (1965) have extended the knowledge',
#    'BoundingBox': {'Width': 0.3353878855705261,
#     'Height': 0.012522394768893719,
#     'Left': 0.139079287648201,
#     'Top': 0.8609117269515991},
#    'Id': '42ee4f9e-1d45-428e-aa85-66eb40e24b91',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.002234991639852524,
#    'height_diff_below': 0.0024941610172390938,
#    'paragraph': 2,
#    'paragraph_std': 2,
#    'top_scl': 0.968140857229914,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.0,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89401245117188,
#    'Text': 'about relationships between concepts, especially also',
#    'BoundingBox': {'Width': 0.3337951600551605,
#     'Height': 0.012812923640012741,
#     'Left': 0.14040112495422363,
#     'Top': 0.8759282827377319},
#    'Id': '9cc4f21e-8e9e-44d3-8a79-cb9eb2c4d056',
#    'Quadrant': 'Q3',
#    'height_diff_above': 0.0024941610172390938,
#    'height_diff_below': 0,
#    'paragraph': 2,
#    'paragraph_std': 2,
#    'top_scl': 1.0,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.07068517776277972,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.74024963378906,
#    'Text': 'Hartmann (1964), presuppose and build themselves',
#    'BoundingBox': {'Width': 0.3330409824848175,
#     'Height': 0.01286800391972065,
#     'Left': 0.5253229141235352,
#     'Top': 0.4045654833316803},
#    'Id': '8992ea29-905e-453c-aa43-110052895bc3',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0,
#    'height_diff_below': 0.002130640670657158,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.04065489267341604,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 0.8987723092388663},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.96100616455078,
#    'Text': 'upon each other, and which can be specified each by',
#    'BoundingBox': {'Width': 0.33397307991981506,
#     'Height': 0.012577424757182598,
#     'Left': 0.5251280665397644,
#     'Top': 0.4195641279220581},
#    'Id': '81985e80-b3fb-4cdb-9779-8ba91d6959ca',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002130640670657158,
#    'height_diff_below': 0.0027741091325879097,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.03181972596534932,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.029450977300847114,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8252944946289,
#    'Text': 'nine aspect areas.',
#    'BoundingBox': {'Width': 0.10765907913446426,
#     'Height': 0.011703946627676487,
#     'Left': 0.5249583721160889,
#     'Top': 0.4349156618118286},
#    'Id': 'ab821410-50d1-4ea8-aeeb-7a6138791967',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0027741091325879097,
#    'height_diff_below': 0.00215896125882864,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.06438810896668068,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.019693391780599256,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.67092895507812,
#    'Text': 'Looking at Figure 2, demonstrating these nine ar-',
#    'BoundingBox': {'Width': 0.3166174590587616,
#     'Height': 0.012809992767870426,
#     'Left': 0.5420069098472595,
#     'Top': 0.44877856969833374},
#    'Id': '3a087a0a-648d-48a8-8dfc-79b16b26c684',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.00215896125882864,
#    'height_diff_below': 0.0019129803404211998,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0937983618314272,
#    'paragraph_scl': 0.0,
#    'left_scl': 1.0,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8458480834961,
#    'Text': 'eas of being, it is obvious that area 8 is the one deal-',
#    'BoundingBox': {'Width': 0.3334934413433075,
#     'Height': 0.013027314096689224,
#     'Left': 0.5253400802612305,
#     'Top': 0.46350154280662537},
#    'Id': 'cdb61af6-3c1e-4abb-b19e-c1416510bbfb',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0019129803404211998,
#    'height_diff_below': 0.001575317233800888,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.12503324888259415,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.04164196138779275,
#    'paragraph_std_scl': 0.0,
# ...
#   {'BlockType': 'LINE',
#    'Confidnece': 99.85804748535156,
#    'Text': 'area are apprehended, which, in the case of area 8,',
#    'BoundingBox': {'Width': 0.3334122598171234,
#     'Height': 0.012476467527449131,
#     'Left': 0.5250061750411987,
#     'Top': 0.5369197130203247},
#    'Id': '7b5d79dd-1085-4f78-b77e-0f05b95d11c4',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0018161972984671593,
#    'height_diff_below': 0.002405858598649502,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.2807903936699312,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.02244210396438362,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.64295196533203,
#    'Text': 'must be "Science of Science." Its subdivisions are',
#    'BoundingBox': {'Width': 0.3335680663585663,
#     'Height': 0.010127690620720387,
#     'Left': 0.5251809358596802,
#     'Top': 0.5518020391464233},
#    'Id': '18eca666-d8ec-4731-af29-0f92b49eedda',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002405858598649502,
#    'height_diff_below': 0.0046965209767222404,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.31236334922640996,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0324910118482542,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.75274658203125,
#    'Text': 'then, i.a., Theory of science, History of science, Sci-',
#    'BoundingBox': {'Width': 0.33376264572143555,
#     'Height': 0.012572777457535267,
#     'Left': 0.5248525142669678,
#     'Top': 0.566626250743866},
#    'Id': '7618690f-b92a-42ca-b0ce-70e3ec907478',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0046965209767222404,
#    'height_diff_below': 0.0021307943388819695,
#    'paragraph': 0,
#    'paragraph_std': 1,
#    'top_scl': 0.34381301441719603,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.013606468041938768,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 3,
#    'cluster_probability': 0.10257992591974958},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.735107421875,
#    'Text': 'ence research, etc. In the ontical area 1, the area of',
#    'BoundingBox': {'Width': 0.3343920111656189,
#     'Height': 0.011474419385194778,
#     'Left': 0.5253630876541138,
#     'Top': 0.5813298225402832},
#    'Id': '78fa9239-5906-4681-ae8a-95995f8ea4a6',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0021307943388819695,
#    'height_diff_below': 0.0032890550792217255,
#    'paragraph': 0,
#    'paragraph_std': 1,
#    'top_scl': 0.3750067414539704,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.042964907650812734,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 3,
#    'cluster_probability': 0.1027046479679621},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87445831298828,
#    'Text': 'Form and Structure, one will find the System Sciences',
#    'BoundingBox': {'Width': 0.3336678743362427,
#     'Height': 0.012430917471647263,
#     'Left': 0.5251202583312988,
#     'Top': 0.5960932970046997},
#    'Id': '1c977777-5ff4-40ce-9af8-f33cbf6bf613',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0032890550792217255,
#    'height_diff_below': 0.002174127846956253,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.4063275524061507,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.029001998128684647,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 0.45366029334752306},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.85283660888672,
#    'Text': 'at the position 4 as a specialty of form and structure.',
#    'BoundingBox': {'Width': 0.3337365686893463,
#     'Height': 0.012683209963142872,
#     'Left': 0.5249855518341064,
#     'Top': 0.6106983423233032},
#    'Id': '3779e59c-d011-4d75-aa6d-5256c14bb0d8',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002174127846956253,
#    'height_diff_below': 0.002114119939506054,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.43731225485370473,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.02125625057836089,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 0.567001712181397},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93025970458984,
#    'Text': 'Therefore it seemed logical for me regarding the sys-',
#    'BoundingBox': {'Width': 0.33394116163253784,
#     'Height': 0.01280184369534254,
#     'Left': 0.5246158838272095,
#     'Top': 0.6254956722259521},
#    'Id': '65904d7b-7c64-4d4c-86e3-67afa8add77e',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002114119939506054,
#    'height_diff_below': 0.0017067017033696175,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.46870489034712937,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.0,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 0.5599053794788181},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.76107788085938,
#    'Text': 'tem character of knowledge, as every knowledge unit',
#    'BoundingBox': {'Width': 0.3334323465824127,
#     'Height': 0.012691988609731197,
#     'Left': 0.525262176990509,
#     'Top': 0.6400042176246643},
#    'Id': '98f217a2-1056-43ca-867e-96f9c0d9d3ca',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0017067017033696175,
#    'height_diff_below': 0.002288863994181156,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.4994848675618053,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.037162451631921556,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 0.5898062702766689},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8336181640625,
#    'Text': 'is related to another one by its concept characteris-',
#    'BoundingBox': {'Width': 0.3335147202014923,
#     'Height': 0.012420452199876308,
#     'Left': 0.5250869393348694,
#     'Top': 0.6549850702285767},
#    'Id': '35489b64-113b-4d3c-88a8-c4de1189765f',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002288863994181156,
#    'height_diff_below': 0.002314233221113682,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.5312668477075042,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.02708612517265152,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89812469482422,
#    'Text': 'tics, to place knowledge organization at position 4 of',
#    'BoundingBox': {'Width': 0.33462485671043396,
#     'Height': 0.012876151129603386,
#     'Left': 0.5252878069877625,
#     'Top': 0.6697197556495667},
#    'Id': 'ecdee2c9-c17c-4c08-9abd-c7916e069f52',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002314233221113682,
#    'height_diff_below': 0.0017465967684984207,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.5625265825092953,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.038636200059638526,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86799621582031,
#    'Text': 'science of science under 81, thus 814.',
#    'BoundingBox': {'Width': 0.2303113043308258,
#     'Height': 0.011339639313519001,
#     'Left': 0.5252761244773865,
#     'Top': 0.6843425035476685},
#    'Id': 'b55348c4-e8b7-434d-a55f-df178d04e3b8',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0017465967684984207,
#    'height_diff_below': 0.0032491935417056084,
#    'paragraph': 0,
#    'paragraph_std': 2,
#    'top_scl': 0.5935488410990142,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.03796444496235196,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 3,
#    'cluster_probability': 0.5855108297694978},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87207794189453,
#    'Text': 'This should be regarded as a proposition only,',
#    'BoundingBox': {'Width': 0.3171409070491791,
#     'Height': 0.012939102947711945,
#     'Left': 0.541486918926239,
#     'Top': 0.6989313364028931},
#    'Id': 'd4540dc6-3a1c-4fe8-84cd-b1a28265b994',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0032491935417056084,
#    'height_diff_below': 0.001690201461315155,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.6244991486958313,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.9701000435269904,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': -1,
#    'cluster_probability': 0.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90852355957031,
#    'Text': 'along with the entire system of knowledge fields, as',
#    'BoundingBox': {'Width': 0.33355775475502014,
#     'Height': 0.012844284065067768,
#     'Left': 0.5249180197715759,
#     'Top': 0.7135606408119202},
#    'Id': 'b53bfb3c-437f-49e1-ad17-b4409445c018',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.001690201461315155,
#    'height_diff_below': 0.002088288776576519,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.6555353169678335,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.01737309483742777,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 0.7431806601953872},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93719482421875,
#    'Text': 'represented by this universal classification system,',
#    'BoundingBox': {'Width': 0.33351144194602966,
#     'Height': 0.012587308883666992,
#     'Left': 0.5250533223152161,
#     'Top': 0.7284932136535645},
#    'Id': '51d19172-f5d8-499a-869c-2d0a9c299d5b',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002088288776576519,
#    'height_diff_below': 0.0018532276153564453,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.6872148712712647,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.02515311560699729,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.95173645019531,
#    'Text': 'under which nearly 7000 concepts of knowledge or',
#    'BoundingBox': {'Width': 0.3343520164489746,
#     'Height': 0.012896900996565819,
#     'Left': 0.5249406695365906,
#     'Top': 0.7429337501525879},
#    'Id': '5caec02a-0723-447d-8bf3-256afd8a5916',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0018532276153564453,
#    'height_diff_below': 0.0019047204405069351,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.717850567145166,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.01867547716889817,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87257385253906,
#    'Text': 'subject fields (and not as yet their contents) on a',
#    'BoundingBox': {'Width': 0.33362892270088196,
#     'Height': 0.012811578810214996,
#     'Left': 0.5253269672393799,
#     'Top': 0.7577353715896606},
#    'Id': '65396079-4f84-42f5-994f-acc608bb0b01',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0019047204405069351,
#    'height_diff_below': 0.0019398555159568787,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.7492523071579036,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.04088795056431138,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88076782226562,
#    'Text': 'number of subdivisional levels were elaborated on',
#    'BoundingBox': {'Width': 0.3334522545337677,
#     'Height': 0.010334289632737637,
#     'Left': 0.5252485275268555,
#     'Top': 0.7724868059158325},
#    'Id': '74f0c6ab-4298-44f4-b98b-2dec7c7c80e4',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0019398555159568787,
#    'height_diff_below': 0.0043222540989518166,
#    'paragraph': 0,
#    'paragraph_std': 3,
#    'top_scl': 0.7805475748753457,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.036377594911112254,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 0.6907016071277317},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90685272216797,
#    'Text': 'the basis of their definitions. (The definitions were',
#    'BoundingBox': {'Width': 0.3336918354034424,
#     'Height': 0.012592428363859653,
#     'Left': 0.525014340877533,
#     'Top': 0.787143349647522},
#    'Id': 'c980fee8-5295-4f0a-8b4d-a5fc1ae82da9',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0043222540989518166,
#    'height_diff_below': 0.0023245876654982567,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.8116415315546517,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.022911647068099228,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.6156250661038203},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.24414825439453,
#    'Text': 'taken from encyclopedias, from Wahrig (1975), and',
#    'BoundingBox': {'Width': 0.3334186375141144,
#     'Height': 0.012646198272705078,
#     'Left': 0.5253139138221741,
#     'Top': 0.8020603656768799},
#    'Id': 'dbaf87bf-b14d-4851-9533-0f9a94a762f7',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0023245876654982567,
#    'height_diff_below': 0.001861870288848877,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.8432880819755746,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.040137367062751395,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.906831103137086},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.73551940917969,
#    'Text': 'from 500 special dictionaries. They were discussed',
#    'BoundingBox': {'Width': 0.33338937163352966,
#     'Height': 0.012670758180320263,
#     'Left': 0.525282084941864,
#     'Top': 0.8165684342384338},
#    'Id': '8124a8ba-fdeb-4c09-a074-724529806ce7',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.001861870288848877,
#    'height_diff_below': 0.002367374487221241,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.8740670475769934,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.03830717715484511,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.906831103137086},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.94087982177734,
#    'Text': 'with almost 300 university teachers. In this sense it',
#    'BoundingBox': {'Width': 0.3338460326194763,
#     'Height': 0.012421375140547752,
#     'Left': 0.5249839425086975,
#     'Top': 0.8316065669059753},
#    'Id': '59991267-bf57-4789-a72e-b3592facbb19',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002367374487221241,
#    'height_diff_below': 0.0020683351904153824,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.9059705477651852,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.021163712886387742,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.906831103137086},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89791870117188,
#    'Text': "forms, expressed in today's pertinent terminology,",
#    'BoundingBox': {'Width': 0.33323338627815247,
#     'Height': 0.012800750322639942,
#     'Left': 0.5252733826637268,
#     'Top': 0.8460962772369385},
#    'Id': '6240be9a-afbb-4f5a-b718-b78f4e428549',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0020683351904153824,
#    'height_diff_below': 0.0021192459389567375,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.936710566256211,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.037806788153805115,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.70454406738281,
#    'Text': 'an "upper ontology.") The system could well be used',
#    'BoundingBox': {'Width': 0.33380773663520813,
#     'Height': 0.012697922065854073,
#     'Left': 0.525037944316864,
#     'Top': 0.8610162734985352},
#    'Id': '782a277d-d1fd-42e7-a050-bbb007196b9d',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0021192459389567375,
#    'height_diff_below': 0.0022143851965665817,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 0.9683634392599898,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.02426886655036853,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93197631835938,
#    'Text': 'for the purpose mentioned in the next chapter, but it',
#    'BoundingBox': {'Width': 0.33332082629203796,
#     'Height': 0.012534487061202526,
#     'Left': 0.5252566337585449,
#     'Top': 0.8759285807609558},
#    'Id': 'df1d0b92-20cc-4b89-a3ff-f12105da85fb',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0022143851965665817,
#    'height_diff_below': 0,
#    'paragraph': 0,
#    'paragraph_std': 4,
#    'top_scl': 1.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.03684371069290293,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.6344184281493259}],
#  'file_name': 'Sample 1.pdf'}

# %% [markdown]
# ## Retrieve File Results

# %%
s3 = boto3_session('resouce')
res_files = read_s3_subfiles_src(s3, 'T2_Model')
res_files
# Out:
# ['T2_Model/Sample 1.json',
#  'T2_Model/Sample 10.json',
#  'T2_Model/Sample 11.json',
#  'T2_Model/Sample 12.json',
#  'T2_Model/Sample 13.json',
#  'T2_Model/Sample 14.json',
#  'T2_Model/Sample 15.json',
#  'T2_Model/Sample 16.json',
#  'T2_Model/Sample 17.json',
#  'T2_Model/Sample 18.json',
#  'T2_Model/Sample 19.json',
#  'T2_Model/Sample 2.json',
#  'T2_Model/Sample 20.json',
#  'T2_Model/Sample 21.json',
#  'T2_Model/Sample 22.json',
#  'T2_Model/Sample 23.json',
#  'T2_Model/Sample 24.json',
#  'T2_Model/Sample 25.json',
#  'T2_Model/Sample 26.json',
#  'T2_Model/Sample 27.json',
#  'T2_Model/Sample 28.json',
#  'T2_Model/Sample 29.json',
#  'T2_Model/Sample 3.json',
#  'T2_Model/Sample 30.json',
#  'T2_Model/Sample 31.json',
#  'T2_Model/Sample 32.json',
#  'T2_Model/Sample 33.json',
#  'T2_Model/Sample 34.json',
#  'T2_Model/Sample 35.json',
#  'T2_Model/Sample 36.json',
#  'T2_Model/Sample 37.json',
#  'T2_Model/Sample 38.json',
#  'T2_Model/Sample 39.json',
#  'T2_Model/Sample 4.json',
#  'T2_Model/Sample 40.json',
#  'T2_Model/Sample 41.json',
#  'T2_Model/Sample 42.json',
#  'T2_Model/Sample 43.json',
#  'T2_Model/Sample 44.json',
#  'T2_Model/Sample 45.json',
#  'T2_Model/Sample 46.json',
#  'T2_Model/Sample 47.json',
#  'T2_Model/Sample 48.json',
#  'T2_Model/Sample 49.json',
#  'T2_Model/Sample 5.json',
#  'T2_Model/Sample 50.json',
#  'T2_Model/Sample 51.json',
#  'T2_Model/Sample 52.json',
#  'T2_Model/Sample 53.json',
#  'T2_Model/Sample 54.json',
#  'T2_Model/Sample 55.json',
#  'T2_Model/Sample 56.json',
#  'T2_Model/Sample 57.json',
#  'T2_Model/Sample 58.json',
#  'T2_Model/Sample 59.json',
#  'T2_Model/Sample 6.json',
#  'T2_Model/Sample 60.json',
#  'T2_Model/Sample 7.json',
#  'T2_Model/Sample 8.json',
#  'T2_Model/Sample 9.json']

# %%
for file in res_files: 
    file_name = file.split('/')[-1]
    j_obj = retrieve_s3_subfile(s3, file)

    # Serializing json
    json_object = json.dumps(j_obj, indent=4)
    
    # Writing to sample.json
    with open(f'Export Data/T2 Model Results/{file_name}', "w") as outfile:
        outfile.write(json_object)
