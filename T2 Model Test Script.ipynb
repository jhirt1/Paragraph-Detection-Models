# %%
import datetime
import boto3
import botocore
import pandas as pd
import numpy as np
import json
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import DBSCAN, Birch
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import hdbscan

import warnings
warnings.filterwarnings("ignore")

# %%
############################
#     AWS Functions        #
############################

def boto3_session(flavor):
  """
  boto3_session instantiates an AWS session. 
  
  :flavor: indicates if the session should be created at the client or the resouce level
  :return: session
  """

  if flavor == 'client':
    return(boto3.client('s3', 'us-east-2'))
  else:
    return(boto3.resource('s3', 'us-east-2'))


def write_to_s3(sesh, key, obj):
  """
  write_to_s3 will write textract formatted results to the artifact bucket using the provided key.
  
  :sesh: S3 session
  :key: the prefix and key for the object in S3
  """
  
  sesh.Object('uwm-textract-910', key).put(Body=bytes(json.dumps(obj).encode('UTF-8')))
  return

def read_s3_subfiles_src(s3_sesh, prefix):
  """
  read_s3_subfiles gathers all of the object keys from a specific directory in S3.
  
  :session: a boto3 resouce session
  :folder: the directory for inspection
  :return: an array of object keys
  """
  bucket_src = s3_sesh.Bucket('uwm-textract-910')
  files = []
  

  for object_summary in bucket_src.objects.filter(Prefix=prefix):
    if object_summary.key.endswith('.json'):
        files.append(object_summary.key)

    #remove for live automation
    # if len(files) == 1000:
    #     break
  
  return files

def retrieve_s3_subfile (s3_sesh, file):
  
  con_obj = s3_sesh.Object('uwm-textract-910', file)
  file_content = con_obj.get()['Body'].read().decode('utf-8')
  json_content = json.loads(file_content)
  
  return json_content

############################
#       METADATA           #
############################

def append_height_diff_above(json_page):
    for i in range(len(json_page['Blocks']) - 1):
        previous_line = i
        current_line = i + 1
            
        previous_font_size = json_page['Blocks'][previous_line]['BoundingBox']['Height']
        current_t = json_page['Blocks'][current_line]['BoundingBox']['Top']
        previous_t = json_page['Blocks'][previous_line]['BoundingBox']['Top']
        height_diff = current_t - (previous_t + previous_font_size)
        # ive tested with absolute value but do we want the possibility of negative differences?
        json_page['Blocks'][current_line]['height_diff_above'] = abs(height_diff)

    json_page['Blocks'][0]['height_diff_above'] = 0
    return json_page
  
  
def append_height_diff_below(json_page):
    for i in range(len(json_page['Blocks']) - 1):
        previous_line = i
        current_line = i + 1
            
        previous_font_size = json_page['Blocks'][previous_line]['BoundingBox']['Height']
        current_t = json_page['Blocks'][current_line]['BoundingBox']['Top']
        previous_t = json_page['Blocks'][previous_line]['BoundingBox']['Top']
        height_diff = current_t - (previous_t + previous_font_size)
        # ive tested with absolute value but do we want the possibility of negative differences?
        json_page['Blocks'][previous_line]['height_diff_below'] = abs(height_diff)

    json_page['Blocks'][-1]['height_diff_below'] = 0
    return json_page

  
def append_paragraph_number(json_page):
    blocks = json_page['Blocks']
    precision = 2
    p_count = 0
    for i in range(len(json_page['Blocks'])):
        below = round(json_page['Blocks'][i]['height_diff_below'],precision)
        above = round(json_page['Blocks'][i]['height_diff_above'],precision)
        if above > below:
            p_count +=1
        json_page['Blocks'][i]['paragraph'] = p_count
    return json_page

  
def append_paragraph_number_std(json_page):
    blocks = json_page['Blocks']
    data = pd.json_normalize(blocks)
    p_counter = 0 
    p_counts = []
    # remove first observation from calculation since it
    # has a zero in it since first line doesnt have a height above
    height_diff_std = data.height_diff_above.iloc[1::].std()
    height_diff_mean = data.height_diff_above.iloc[1::].mean()
    json_page['height_diff_mean'] = height_diff_mean
    json_page['height_diff_std'] = height_diff_std
    
    for i in range(len(json_page['Blocks'])):
        if json_page['Blocks'][i]['height_diff_above'] > (height_diff_mean+height_diff_std):
            p_counter+=1
        json_page['Blocks'][i]['paragraph_std'] = p_counter
    return json_page
      
      
def append_scaled(json_page):
    blocks = json_page['Blocks']
    data = pd.json_normalize(blocks)
    feats = ['BoundingBox.Top', 'BoundingBox.Left', 'paragraph_std', 'paragraph']
    X = data[feats]
    
    scaler = MinMaxScaler()
    X_scl = scaler.fit_transform(X)
    dim1 = X_scl.shape[0]
    dim2 = X_scl.shape[-1]
    for i in range(dim1):
        for j in range(dim2):
            if j==0:
                json_page['Blocks'][i]['top_scl'] = X_scl[i][j]
            if j == 1:
                json_page['Blocks'][i]['left_scl'] = X_scl[i][j]
            elif j == 2:
                json_page['Blocks'][i]['paragraph_std_scl'] = X_scl[i][j]
            else:
                json_page['Blocks'][i]['paragraph_scl'] = X_scl[i][j]
    return json_page
        

def append_cluster(json_page, pca=True):
    blocks = json_page['Blocks']
    feats = ['top_scl', 'left_scl', 'paragraph_std_scl']
    X_scl = pd.json_normalize(blocks)[feats]

    if pca:
        pca = PCA(n_components=2)
        pca_out = pca.fit_transform(X_scl)

        clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
        clusterer.fit(pca_out)
        hdbscan_labels = clusterer.labels_
        cluster_probs = clusterer.probabilities_
    else:
        clusterer = hdbscan.HDBSCAN(min_cluster_size=2)
        clusterer.fit(pca_out)
        hdbscan_labels = clusterer.labels_
        cluster_probs = clusterer.probabilities_


    for i in range(len(json_page['Blocks'])):
        json_page['Blocks'][i]['text_cluster'] = int(hdbscan_labels[i])
        json_page['Blocks'][i]['cluster_probability'] = float(cluster_probs[i])

    return json_page

# %%
s3_sesh = boto3_session('resource')
target = f'Textract_Output'
files = read_s3_subfiles_src(s3_sesh, target)
print(files)
# Out:
# ['Textract_Output/Sample 1.json', 'Textract_Output/Sample 10.json', 'Textract_Output/Sample 11.json', 'Textract_Output/Sample 12.json', 'Textract_Output/Sample 13.json', 'Textract_Output/Sample 14.json', 'Textract_Output/Sample 15.json', 'Textract_Output/Sample 16.json', 'Textract_Output/Sample 17.json', 'Textract_Output/Sample 18.json', 'Textract_Output/Sample 19.json', 'Textract_Output/Sample 2.json', 'Textract_Output/Sample 20.json', 'Textract_Output/Sample 21.json', 'Textract_Output/Sample 22.json', 'Textract_Output/Sample 23.json', 'Textract_Output/Sample 24.json', 'Textract_Output/Sample 25.json', 'Textract_Output/Sample 26.json', 'Textract_Output/Sample 27.json', 'Textract_Output/Sample 28.json', 'Textract_Output/Sample 29.json', 'Textract_Output/Sample 3.json', 'Textract_Output/Sample 30.json', 'Textract_Output/Sample 31.json', 'Textract_Output/Sample 32.json', 'Textract_Output/Sample 33.json', 'Textract_Output/Sample 34.json', 'Textract_Output/Sample 35.json', 'Textract_Output/Sample 36.json', 'Textract_Output/Sample 37.json', 'Textract_Output/Sample 38.json', 'Textract_Output/Sample 39.json', 'Textract_Output/Sample 4.json', 'Textract_Output/Sample 40.json', 'Textract_Output/Sample 41.json', 'Textract_Output/Sample 42.json', 'Textract_Output/Sample 43.json', 'Textract_Output/Sample 44.json', 'Textract_Output/Sample 45.json', 'Textract_Output/Sample 46.json', 'Textract_Output/Sample 47.json', 'Textract_Output/Sample 48.json', 'Textract_Output/Sample 49.json', 'Textract_Output/Sample 5.json', 'Textract_Output/Sample 50.json', 'Textract_Output/Sample 51.json', 'Textract_Output/Sample 52.json', 'Textract_Output/Sample 53.json', 'Textract_Output/Sample 54.json', 'Textract_Output/Sample 55.json', 'Textract_Output/Sample 56.json', 'Textract_Output/Sample 57.json', 'Textract_Output/Sample 58.json', 'Textract_Output/Sample 59.json', 'Textract_Output/Sample 6.json', 'Textract_Output/Sample 60.json', 'Textract_Output/Sample 7.json', 'Textract_Output/Sample 8.json', 'Textract_Output/Sample 9.json']

# %%
page = retrieve_s3_subfile(s3_sesh, files[3])
page
# Out:
# {'Page': 1,
#  'Blocks': [{'BlockType': 'LINE',
#    'Confidnece': 99.91316223144531,
#    'Text': '602',
#    'BoundingBox': {'Width': 0.02108588255941868,
#     'Height': 0.007797531317919493,
#     'Left': 0.09483252465724945,
#     'Top': 0.06895650923252106},
#    'Id': '55217c52-606c-44c5-9e53-a177056dcec3'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.25527954101562,
#    'Text': 'Knowl. Org. 46(2019)No.8',
#    'BoundingBox': {'Width': 0.1567317545413971,
#     'Height': 0.011315872892737389,
#     'Left': 0.7480316758155823,
#     'Top': 0.07095503807067871},
#    'Id': '496002de-a71a-462c-a4be-84543ace97f4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.46185302734375,
#    'Text': 'V. Broughton. The Respective Roles of Intellectual Creativity and Automation in Representing Diversity',
#    'BoundingBox': {'Width': 0.6103330254554749,
#     'Height': 0.01169310137629509,
#     'Left': 0.29476508498191833,
#     'Top': 0.08680137991905212},
#    'Id': 'b2a6c83f-390c-4afa-aa3e-aec08f1e6ffd'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88697052001953,
#    'Text': '6.0 What solutions exist to the problem of bias?',
#    'BoundingBox': {'Width': 0.33781924843788147,
#     'Height': 0.011731196194887161,
#     'Left': 0.0949084460735321,
#     'Top': 0.12965281307697296},
#    'Id': 'eb9d6d5f-3d89-420b-8454-1d729985a704'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89276123046875,
#    'Text': 'how serious these efforts are. We learn of a Christian robot',
#    'BoundingBox': {'Width': 0.3766983449459076,
#     'Height': 0.009575417265295982,
#     'Left': 0.5280101895332336,
#     'Top': 0.12967661023139954},
#    'Id': '28a1ca76-5442-4552-8ec7-29ee517308f0'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.79305267333984,
#    'Text': 'priest in Wittenberg which radiates light from its hands and',
#    'BoundingBox': {'Width': 0.3758659064769745,
#     'Height': 0.011993678286671638,
#     'Left': 0.5282886624336243,
#     'Top': 0.14491046965122223},
#    'Id': 'ae3f1c77-9945-4dac-8402-25a341805a36'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.83282470703125,
#    'Text': 'As is the case in library and information science, where the',
#    'BoundingBox': {'Width': 0.3764599561691284,
#     'Height': 0.011773200705647469,
#     'Left': 0.09480489790439606,
#     'Top': 0.15979905426502228},
#    'Id': '4d87a5f0-b327-40a9-9a6e-7a1119c5700a'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86279296875,
#    'Text': 'pronounces blessings in five languages as part of an exhibi-',
#    'BoundingBox': {'Width': 0.3764525055885315,
#     'Height': 0.012135554105043411,
#     'Left': 0.527992308139801,
#     'Top': 0.15997710824012756},
#    'Id': 'd7ab59e3-532d-4e3f-a85d-30a903d50883'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90006256103516,
#    'Text': 'interests and priorities of the user community demand a',
#    'BoundingBox': {'Width': 0.3770406246185303,
#     'Height': 0.012003093957901001,
#     'Left': 0.09456600248813629,
#     'Top': 0.17487725615501404},
#    'Id': 'a5e1dd34-3fcb-4f6b-ae54-1fd22fc85fb9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90332794189453,
#    'Text': 'tion to celebrate 500 years since the invention of printing',
#    'BoundingBox': {'Width': 0.3762308955192566,
#     'Height': 0.012552817352116108,
#     'Left': 0.5286509990692139,
#     'Top': 0.17480230331420898},
#    'Id': '1f5f52ee-2360-4f25-ad01-4c1ecb7d1ca1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89124298095703,
#    'Text': 'privileging of those interests, bias is not always regarded as',
#    'BoundingBox': {'Width': 0.37632033228874207,
#     'Height': 0.012124991044402122,
#     'Left': 0.09480556845664978,
#     'Top': 0.18992850184440613},
#    'Id': '22aab730-ac3f-4eb4-8e93-4dd8bad17d7c'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88679504394531,
#    'Text': 'technology, instrumental in the Reformation and the rise of',
#    'BoundingBox': {'Width': 0.37544211745262146,
#     'Height': 0.011784248985350132,
#     'Left': 0.528640866279602,
#     'Top': 0.19025744497776031},
#    'Id': 'ea189b39-0b28-4694-873e-50d2221a002e'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.50320434570312,
#    'Text': 'a bad thing. It is generally agreed that the very fact of a spe-',
#    'BoundingBox': {'Width': 0.3767316937446594,
#     'Height': 0.012356039136648178,
#     'Left': 0.09461289644241333,
#     'Top': 0.2048988789319992},
#    'Id': '1507f753-3364-4f19-a144-a768a81dba26'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.5811996459961,
#    'Text': 'Protestantism (Sherwood 2017). Other cases include a robot',
#    'BoundingBox': {'Width': 0.3765428066253662,
#     'Height': 0.011895670555531979,
#     'Left': 0.528249204158783,
#     'Top': 0.20527370274066925},
#    'Id': '64e11172-9fc7-412c-9ea0-9791b184bb33'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.72636413574219,
#    'Text': 'cific perspective unwittingly and unavoidably generates bias',
#    'BoundingBox': {'Width': 0.3760533034801483,
#     'Height': 0.012151532806456089,
#     'Left': 0.09495176374912262,
#     'Top': 0.22010453045368195},
#    'Id': '37a6ae00-5499-4621-9c60-e52991d2dee7'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.77484130859375,
#    'Text': 'Buddhist monk in China (Tatlow 2016) which reads scrip-',
#    'BoundingBox': {'Width': 0.37606844305992126,
#     'Height': 0.012240190990269184,
#     'Left': 0.5281355977058411,
#     'Top': 0.22030824422836304},
#    'Id': '5d063984-00b4-4140-be51-812365680e5d'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89556121826172,
#    'Text': 'towards the favoured group (such as classification schemes',
#    'BoundingBox': {'Width': 0.3758966624736786,
#     'Height': 0.012408352456986904,
#     'Left': 0.09516475349664688,
#     'Top': 0.23490259051322937},
#    'Id': 'fcc478b6-3828-4c11-ab0e-f1e1b4b4261f'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90193939208984,
#    'Text': 'ture and can answer questions, and another in Japan (Field',
#    'BoundingBox': {'Width': 0.37583106756210327,
#     'Height': 0.012101532891392708,
#     'Left': 0.5286327004432678,
#     'Top': 0.2356436550617218},
#    'Id': 'c17e58c1-2235-495a-91e2-c6a7d24a4cf1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.7144546508789,
#    'Text': 'for libraries with specific religious affiliations). Given the im-',
#    'BoundingBox': {'Width': 0.37548691034317017,
#     'Height': 0.012202044948935509,
#     'Left': 0.09539095312356949,
#     'Top': 0.250205934047699},
#    'Id': 'fd88ff1a-fd93-49fc-b2cb-91d2517129ee'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.80352020263672,
#    'Text': '2017) which can "chant prayers and tap drums as part of a',
#    'BoundingBox': {'Width': 0.37658852338790894,
#     'Height': 0.012213857844471931,
#     'Left': 0.5281904339790344,
#     'Top': 0.2505841553211212},
#    'Id': 'd635fb07-02fb-440d-b324-d66f4082c7de'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92333221435547,
#    'Text': 'portance of meeting user expectations and the needs of the',
#    'BoundingBox': {'Width': 0.3765539526939392,
#     'Height': 0.01197957992553711,
#     'Left': 0.09482860565185547,
#     'Top': 0.26549357175827026},
#    'Id': '27b1dbb1-421a-48df-a413-6c023b125776'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.41353607177734,
#    'Text': 'funeral ceremony."',
#    'BoundingBox': {'Width': 0.11900794506072998,
#     'Height': 0.011789669282734394,
#     'Left': 0.5286258459091187,
#     'Top': 0.2657643258571625},
#    'Id': '983fe4ce-744e-4eea-b040-9e891c0ddd1e'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.80525207519531,
#    'Text': 'user community, bias can be seen as an ethically-neutral phe-',
#    'BoundingBox': {'Width': 0.3760238587856293,
#     'Height': 0.012068710289895535,
#     'Left': 0.09503913670778275,
#     'Top': 0.2803056836128235},
#    'Id': '26c9bf4b-9e79-4f62-bb82-8b163f5210a4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88520050048828,
#    'Text': 'There is also a literature in the overlap between religious',
#    'BoundingBox': {'Width': 0.3577140271663666,
#     'Height': 0.012247630394995213,
#     'Left': 0.546582043170929,
#     'Top': 0.28074708580970764},
#    'Id': '8dfc6463-72ff-4aae-974f-1dfa391e9c4b'},
#   {'BlockType': 'LINE',
#    'Confidnece': 97.95367431640625,
#    'Text': 'nomenon.',
#    'BoundingBox': {'Width': 0.06425191462039948,
#     'Height': 0.006272295489907265,
#     'Left': 0.09503266215324402,
#     'Top': 0.29816174507141113},
#    'Id': '432d507f-e593-4f00-bc2d-2163926d2aa0'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.67941284179688,
#    'Text': 'philosophy and AI that considers the nature of the relation-',
#    'BoundingBox': {'Width': 0.37660345435142517,
#     'Height': 0.012136672623455524,
#     'Left': 0.5278559327125549,
#     'Top': 0.29578784108161926},
#    'Id': 'fb391ab8-c2a6-4e9d-bda6-610cb44d86be'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90630340576172,
#    'Text': 'In other cases the investigation of bias is simply a part',
#    'BoundingBox': {'Width': 0.3574582636356354,
#     'Height': 0.012164248153567314,
#     'Left': 0.11392226070165634,
#     'Top': 0.31058409810066223},
#    'Id': '4955c6bd-fe5a-4316-9907-9153c9d66be9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90760803222656,
#    'Text': 'ships between intelligent agents, humans and the person of',
#    'BoundingBox': {'Width': 0.3759653866291046,
#     'Height': 0.012075015343725681,
#     'Left': 0.528329074382782,
#     'Top': 0.3110232651233673},
#    'Id': 'e113541c-31b2-4ed1-b540-4ff629b9ad70'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.94483184814453,
#    'Text': 'of the scholarly study of society and the legitimate search',
#    'BoundingBox': {'Width': 0.37624308466911316,
#     'Height': 0.0121960723772645,
#     'Left': 0.0948060005903244,
#     'Top': 0.3254318833351135},
#    'Id': 'f7081e82-8980-4e9a-87a0-b25cf5f403a9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89513397216797,
#    'Text': 'God, typically whether the creation of intelligent agents in',
#    'BoundingBox': {'Width': 0.3760621249675751,
#     'Height': 0.012339175678789616,
#     'Left': 0.528546154499054,
#     'Top': 0.3257470726966858},
#    'Id': '950d43f8-07ff-40d3-a169-aaa11cfce73b'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.80177307128906,
#    'Text': 'for patterns and trends in human cultures. For example, a',
#    'BoundingBox': {'Width': 0.3763110935688019,
#     'Height': 0.012347143143415451,
#     'Left': 0.09518346935510635,
#     'Top': 0.3406359851360321},
#    'Id': '991c56be-bc9d-499d-bb6a-5b1d182b18e1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.63331604003906,
#    'Text': 'some sense mirrors the creation of humans (Herzfeld',
#    'BoundingBox': {'Width': 0.3762444257736206,
#     'Height': 0.011819596402347088,
#     'Left': 0.5284622311592102,
#     'Top': 0.3410319685935974},
#    'Id': 'a5ae837e-aa00-427b-bdf3-f93675b4500c'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.76185607910156,
#    'Text': 'paper by Kozlowski et al. (2019, 38) shows how the ma-',
#    'BoundingBox': {'Width': 0.37620362639427185,
#     'Height': 0.012097017839550972,
#     'Left': 0.09489978104829788,
#     'Top': 0.35569047927856445},
#    'Id': 'aa429de2-72a2-4fc5-9b08-59f1cf92f15f'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78422546386719,
#    'Text': '2003), and if the possibilities of transhumanism through the',
#    'BoundingBox': {'Width': 0.37643900513648987,
#     'Height': 0.012303187511861324,
#     'Left': 0.5281985402107239,
#     'Top': 0.3559752106666565},
#    'Id': '92689bc7-a143-461c-9137-63e5f42f58ce'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87232971191406,
#    'Text': 'chine analytical technique of word embedding can help to',
#    'BoundingBox': {'Width': 0.37591230869293213,
#     'Height': 0.012308747507631779,
#     'Left': 0.09516910463571548,
#     'Top': 0.3708515763282776},
#    'Id': '1ec7e9db-39bc-4026-b007-8f8e0703050e'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.81466674804688,
#    'Text': 'technological alteration of species are realizable (Dumsday',
#    'BoundingBox': {'Width': 0.3765164911746979,
#     'Height': 0.012286149896681309,
#     'Left': 0.5285925269126892,
#     'Top': 0.37106624245643616},
#    'Id': 'c67fe027-6438-4bda-964b-f2f007d1eb99'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91606903076172,
#    'Text': 'reveal changes in social attitudes over time and historic',
#    'BoundingBox': {'Width': 0.37604373693466187,
#     'Height': 0.011891546659171581,
#     'Left': 0.09514276683330536,
#     'Top': 0.38596704602241516},
#    'Id': 'fe27bb6f-8cd0-4209-98ba-6a57d8f7a7aa'},
#   {'BlockType': 'LINE',
#    'Confidnece': 98.5512924194336,
#    'Text': "2017). Vidal (2007, 930) makes a comparison between man's",
#    'BoundingBox': {'Width': 0.37632691860198975,
#     'Height': 0.012158150784671307,
#     'Left': 0.5281582474708557,
#     'Top': 0.3861873745918274},
#    'Id': 'e966f040-1fc8-4b01-a064-c1f716492828'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.39083862304688,
#    'Text': 'changes in word meanings. In different situations, the',
#    'BoundingBox': {'Width': 0.3764856457710266,
#     'Height': 0.011872378177940845,
#     'Left': 0.09490784257650375,
#     'Top': 0.40116995573043823},
#    'Id': '193fcf7b-9f69-4b52-8754-aabe30b4864d'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87794494628906,
#    'Text': 'interaction with artificial beings and his interactions with the',
#    'BoundingBox': {'Width': 0.37674808502197266,
#     'Height': 0.011974268592894077,
#     'Left': 0.5279977917671204,
#     'Top': 0.4013622999191284},
#    'Id': '7678e0e8-3e57-49cf-9f1b-175c06bbd682'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.91513061523438,
#    'Text': 'identification of bias may be the preliminary to addressing',
#    'BoundingBox': {'Width': 0.3769414722919464,
#     'Height': 0.012470469810068607,
#     'Left': 0.09434651583433151,
#     'Top': 0.4159667193889618},
#    'Id': '0309cc68-6a26-4298-ae7a-6c6d02ad8890'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88965606689453,
#    'Text': 'gods, asking whether the similarities are not caused by un-',
#    'BoundingBox': {'Width': 0.3763725757598877,
#     'Height': 0.01213967613875866,
#     'Left': 0.5279744267463684,
#     'Top': 0.41641929745674133},
#    'Id': 'a4fbb4e5-236a-43e3-a454-5e929fc0eedc'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92733764648438,
#    'Text': 'it in a social and political context, and is a useful tool in',
#    'BoundingBox': {'Width': 0.3764691650867462,
#     'Height': 0.012054173275828362,
#     'Left': 0.09472506493330002,
#     'Top': 0.4312998950481415},
#    'Id': '2666f1e4-e59b-41c3-9786-f87454c8b023'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.810302734375,
#    'Text': 'certainty:',
#    'BoundingBox': {'Width': 0.057482946664094925,
#     'Height': 0.011118726804852486,
#     'Left': 0.5284923315048218,
#     'Top': 0.4321962594985962},
#    'Id': 'e46693fa-2f33-4a11-8475-6a9c82651bf4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.69832611083984,
#    'Text': 'highlighting social inequalities.',
#    'BoundingBox': {'Width': 0.196974515914917,
#     'Height': 0.012014202773571014,
#     'Left': 0.09470367431640625,
#     'Top': 0.44651108980178833},
#    'Id': '7aa95294-dabc-4d36-98d7-babb46463d3b'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.85248565673828,
#    'Text': 'In a wider context however, bias should be energetically',
#    'BoundingBox': {'Width': 0.3573087751865387,
#     'Height': 0.012111285701394081,
#     'Left': 0.11375445872545242,
#     'Top': 0.46162185072898865},
#    'Id': '10fcfa71-1fe5-4a89-9acd-cb4fb4b24346'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93927764892578,
#    'Text': 'But it is also true that where interaction is supposed',
#    'BoundingBox': {'Width': 0.33780840039253235,
#     'Height': 0.011987521313130856,
#     'Left': 0.5472887754440308,
#     'Top': 0.46187761425971985},
#    'Id': 'bb137a9b-9631-4835-8b44-3e72ca66f830'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93909454345703,
#    'Text': 'tackled if the system is not to appear as the tool of a par-',
#    'BoundingBox': {'Width': 0.3754130005836487,
#     'Height': 0.012159197591245174,
#     'Left': 0.09525240212678909,
#     'Top': 0.4765579104423523},
#    'Id': 'dca825df-8c18-4687-a70d-99417b7d156d'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88581085205078,
#    'Text': 'to exist between the gods and their worshippers,',
#    'BoundingBox': {'Width': 0.33762651681900024,
#     'Height': 0.01210279855877161,
#     'Left': 0.5474798083305359,
#     'Top': 0.47703441977500916},
#    'Id': 'd3e81fdd-96a2-4887-994f-d754a0d182b1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.49819946289062,
#    'Text': 'ticular cultural, political, or disciplinary community. Bias',
#    'BoundingBox': {'Width': 0.37598296999931335,
#     'Height': 0.01210276409983635,
#     'Left': 0.09503393620252609,
#     'Top': 0.4917222857475281},
#    'Id': 'c0eebb30-4af4-4828-ae04-70aa8938630c'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89601135253906,
#    'Text': 'there always remains a strong element of uncertainty',
#    'BoundingBox': {'Width': 0.3383662700653076,
#     'Height': 0.012020442634820938,
#     'Left': 0.547386646270752,
#     'Top': 0.49205300211906433},
#    'Id': '569bd288-d864-4b73-9574-2636f50e450b'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89889526367188,
#    'Text': 'inherent in data is generally regarded as undesirable and',
#    'BoundingBox': {'Width': 0.37623417377471924,
#     'Height': 0.012128706090152264,
#     'Left': 0.09468366205692291,
#     'Top': 0.5064325332641602},
#    'Id': '0266a531-66c9-48b3-8c01-a3728cf32a32'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88188171386719,
#    'Text': 'which cannot easily be dismissed concerning the ex-',
#    'BoundingBox': {'Width': 0.3381541073322296,
#     'Height': 0.012135365977883339,
#     'Left': 0.5470730662345886,
#     'Top': 0.5070592164993286},
#    'Id': '187e704a-4997-4d2f-b84e-75094726fd60'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88508605957031,
#    'Text': 'has generated an area of research activity under the general',
#    'BoundingBox': {'Width': 0.37666183710098267,
#     'Height': 0.011951008811593056,
#     'Left': 0.09465637803077698,
#     'Top': 0.5216631293296814},
#    'Id': '9268d8a8-d060-4524-bdef-85ec4b1453bf'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88674926757812,
#    'Text': 'act ontological nature of the hybrid arrangement by',
#    'BoundingBox': {'Width': 0.3383806049823761,
#     'Height': 0.012129907496273518,
#     'Left': 0.547204315662384,
#     'Top': 0.5221974849700928},
#    'Id': '747fb7ec-5db4-4b21-b6ca-bb65fc73bb1d'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.45973205566406,
#    'Text': 'heading of machine-learning fairness. Barocas, Hardt, and',
#    'BoundingBox': {'Width': 0.3761901259422302,
#     'Height': 0.012210046872496605,
#     'Left': 0.09478600323200226,
#     'Top': 0.5366207957267761},
#    'Id': 'f434cd98-6c63-48ef-8d11-c873016ddef1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8985366821289,
#    'Text': "which the divinity's presence is made manifest. It is",
#    'BoundingBox': {'Width': 0.338032066822052,
#     'Height': 0.012063227593898773,
#     'Left': 0.5471490025520325,
#     'Top': 0.5371823906898499},
#    'Id': 'b8cc6f1a-d9a2-46a3-8953-f059377923f5'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87796020507812,
#    'Text': 'Narayanan (2018) provide a broadly-based survey of a',
#    'BoundingBox': {'Width': 0.37671077251434326,
#     'Height': 0.012092751450836658,
#     'Left': 0.09457332640886307,
#     'Top': 0.5519794225692749},
#    'Id': '29aa747b-19ac-47ec-83ff-4b1d8431a708'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8282470703125,
#    'Text': 'precisely the same sort of ontological uncertainty',
#    'BoundingBox': {'Width': 0.33800628781318665,
#     'Height': 0.01202689204365015,
#     'Left': 0.5473697781562805,
#     'Top': 0.5521544814109802},
#    'Id': '38163439-f99a-4472-88ba-c8e105077a48'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.5412826538086,
#    'Text': 'number of problems and potential solutions, based on sta-',
#    'BoundingBox': {'Width': 0.3760431408882141,
#     'Height': 0.0119816605001688,
#     'Left': 0.09506426751613617,
#     'Top': 0.5670991539955139},
#    'Id': '05bb251e-3112-4e6d-9346-1953b96ee9c6'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6975326538086,
#    'Text': 'that one finds expressed in the field of robotics. And',
#    'BoundingBox': {'Width': 0.3379596471786499,
#     'Height': 0.011985193006694317,
#     'Left': 0.5473806858062744,
#     'Top': 0.5671889185905457},
#    'Id': 'fa2eed48-83f4-4ecc-ac49-25f8f18f6ad5'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.67052459716797,
#    'Text': 'tistical adjustment. The book "offers a critical take on cur-',
#    'BoundingBox': {'Width': 0.3762914538383484,
#     'Height': 0.011585957370698452,
#     'Left': 0.09481305629014969,
#     'Top': 0.5820197463035583},
#    'Id': '5176f2b1-f784-4c6f-a707-b7ef3051a897'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.9035415649414,
#    'Text': 'this is also why robots both fascinate and worry the',
#    'BoundingBox': {'Width': 0.3379111588001251,
#     'Height': 0.012089177034795284,
#     'Left': 0.5474206209182739,
#     'Top': 0.5822350978851318},
#    'Id': 'e18f9094-33d7-4af4-9ea0-4d45cb6ae7d3'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.834228515625,
#    'Text': 'rent practice of machine learning as well as proposed tech-',
#    'BoundingBox': {'Width': 0.37623298168182373,
#     'Height': 0.012231393717229366,
#     'Left': 0.0948747768998146,
#     'Top': 0.597202718257904},
#    'Id': '07e84338-fbce-4623-ba7c-099de2bca332'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.52567291259766,
#    'Text': 'general public.',
#    'BoundingBox': {'Width': 0.09428026527166367,
#     'Height': 0.01173343975096941,
#     'Left': 0.5468749403953552,
#     'Top': 0.5977197289466858},
#    'Id': 'a5e76928-75e7-4a6f-a0b9-2d2d16e3c15f'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.65599822998047,
#    'Text': 'nical fixes for achieving fairness."',
#    'BoundingBox': {'Width': 0.2164110541343689,
#     'Height': 0.011834491975605488,
#     'Left': 0.09504923224449158,
#     'Top': 0.6123846769332886},
#    'Id': '8ca73f70-9ffb-47c9-9f33-2a08af9153d5'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78559875488281,
#    'Text': 'Mancuhan and Clifton (2014) also propose a statistical',
#    'BoundingBox': {'Width': 0.35710233449935913,
#     'Height': 0.012189575470983982,
#     'Left': 0.11403016746044159,
#     'Top': 0.6274178624153137},
#    'Id': 'd9214eaf-1da5-4a53-a3c8-f510b6ef36c0'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93135070800781,
#    'Text': '6.2 The moral and religious life of machines',
#    'BoundingBox': {'Width': 0.31428366899490356,
#     'Height': 0.012095442041754723,
#     'Left': 0.528290331363678,
#     'Top': 0.6275264024734497},
#    'Id': 'f1f85e6a-975e-400a-8c33-fa0e77cc06e1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.85446166992188,
#    'Text': 'solution to bias in data used for automatic financial deci-',
#    'BoundingBox': {'Width': 0.37617701292037964,
#     'Height': 0.009576015174388885,
#     'Left': 0.0949101448059082,
#     'Top': 0.6425043344497681},
#    'Id': 'cc83d1f8-cfe6-40e6-b128-28e4ce9c3eb2'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.32272338867188,
#    'Text': 'sion-making, employing Bayesian techniques to identify',
#    'BoundingBox': {'Width': 0.37579599022865295,
#     'Height': 0.012160739861428738,
#     'Left': 0.09538482129573822,
#     'Top': 0.6576260328292847},
#    'Id': '5f501566-93f6-492a-b563-96b1e39ed4a1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92827606201172,
#    'Text': 'A pressing question is whether a real sense of moral re-',
#    'BoundingBox': {'Width': 0.3759782314300537,
#     'Height': 0.011910981498658657,
#     'Left': 0.5281528234481812,
#     'Top': 0.658055305480957},
#    'Id': 'f7bfe5d9-ca5b-4e12-b2af-499a831edef2'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.82127380371094,
#    'Text': 'and automatically correct bias. This is incidentally one of',
#    'BoundingBox': {'Width': 0.37619009613990784,
#     'Height': 0.011952213943004608,
#     'Left': 0.09451096504926682,
#     'Top': 0.6727762222290039},
#    'Id': 'bfc9c290-3d6b-453d-a0bc-72474d59c728'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84795379638672,
#    'Text': 'sponsibility can be developed in intelligent agents, or, more',
#    'BoundingBox': {'Width': 0.37622520327568054,
#     'Height': 0.012142231687903404,
#     'Left': 0.5284137725830078,
#     'Top': 0.6730008721351624},
#    'Id': 'a787c10a-6d38-4bf1-bbef-a7c6cceff271'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.90912628173828,
#    'Text': 'the few papers to reference religion as an attribute subject',
#    'BoundingBox': {'Width': 0.3764926493167877,
#     'Height': 0.01206443551927805,
#     'Left': 0.09488555043935776,
#     'Top': 0.6877915263175964},
#    'Id': '201fcecb-f6c5-41bc-ac22-b5cc8914c3d9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84844970703125,
#    'Text': 'fancifully perhaps, a proper religious sense. In human be-',
#    'BoundingBox': {'Width': 0.37574225664138794,
#     'Height': 0.012300929985940456,
#     'Left': 0.5284615159034729,
#     'Top': 0.6879498362541199},
#    'Id': '898ffb43-ff69-4ec8-8448-b5e21cf00004'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.83550262451172,
#    'Text': 'to bias, although the authors do not go on to include it in',
#    'BoundingBox': {'Width': 0.37604406476020813,
#     'Height': 0.01228592824190855,
#     'Left': 0.09500530362129211,
#     'Top': 0.7026122808456421},
#    'Id': '3840c37f-c903-4160-9c8f-d374fb6e11b9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88512420654297,
#    'Text': 'ings, it may seem obvious that ethical decisions differ in',
#    'BoundingBox': {'Width': 0.37620705366134644,
#     'Height': 0.01185592357069254,
#     'Left': 0.528139054775238,
#     'Top': 0.703192412853241},
#    'Id': '5ba7a8ea-6929-40e8-8733-1bf0087ef783'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84821319580078,
#    'Text': 'their study.',
#    'BoundingBox': {'Width': 0.07069601863622665,
#     'Height': 0.011741005815565586,
#     'Left': 0.09513340890407562,
#     'Top': 0.7181650400161743},
#    'Id': 'ff0666b9-4c69-4fa1-b06a-41dcd74f5ea4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.75194549560547,
#    'Text': 'some significant respect from other kinds of decisions,',
#    'BoundingBox': {'Width': 0.37599822878837585,
#     'Height': 0.012068712152540684,
#     'Left': 0.5284170508384705,
#     'Top': 0.7182764410972595},
#    'Id': '0edfaccf-4dae-458a-9c1e-8238458ef448'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87187957763672,
#    'Text': 'and that intellectual reasoning is subordinate to, or at least',
#    'BoundingBox': {'Width': 0.3768402636051178,
#     'Height': 0.012221094220876694,
#     'Left': 0.5278121829032898,
#     'Top': 0.7333305478096008},
#    'Id': '31797f24-f90e-4333-897d-7ac28e5c273a'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.69879913330078,
#    'Text': '6.1 A moral and religious solution',
#    'BoundingBox': {'Width': 0.238028883934021,
#     'Height': 0.011811329051852226,
#     'Left': 0.09469615668058395,
#     'Top': 0.7481310367584229},
#    'Id': 'ded372d4-5c62-47ba-8c01-e66f60d7b059'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6059799194336,
#    'Text': 'strongly influenced by, emotional intelligence. As Liao',
#    'BoundingBox': {'Width': 0.3757619857788086,
#     'Height': 0.01217692531645298,
#     'Left': 0.5282239317893982,
#     'Top': 0.7484709620475769},
#    'Id': '15601a1d-0c5c-48d7-a3a3-c29dfd29d8a9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92679595947266,
#    'Text': '(2016) says:',
#    'BoundingBox': {'Width': 0.0738762766122818,
#     'Height': 0.011374508030712605,
#     'Left': 0.5288876891136169,
#     'Top': 0.7640493512153625},
#    'Id': 'f6e18ead-1b37-4afe-b891-6f68b584807a'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89053344726562,
#    'Text': 'As with every other area of human life, machine intelligence',
#    'BoundingBox': {'Width': 0.37689560651779175,
#     'Height': 0.012073753401637077,
#     'Left': 0.0942993089556694,
#     'Top': 0.7781787514686584},
#    'Id': '874917a5-a9ae-4589-bdec-6973b8ff6322'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.80656433105469,
#    'Text': 'has impacted religious communities, apart from the general',
#    'BoundingBox': {'Width': 0.37681588530540466,
#     'Height': 0.012422571890056133,
#     'Left': 0.09472271054983139,
#     'Top': 0.7931190729141235},
#    'Id': 'cebc90eb-3a83-4135-9c16-d381b11cc845'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89524841308594,
#    'Text': 'Central area of intellectual inquiry across different',
#    'BoundingBox': {'Width': 0.3381929397583008,
#     'Height': 0.01220998540520668,
#     'Left': 0.547482430934906,
#     'Top': 0.7935547232627869},
#    'Id': '8baa7693-76e9-4f75-a733-33de904e82b9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8840103149414,
#    'Text': 'philosophical questions of whether robots can act as moral',
#    'BoundingBox': {'Width': 0.37627580761909485,
#     'Height': 0.012147733010351658,
#     'Left': 0.09510965645313263,
#     'Top': 0.8082432746887207},
#    'Id': '356d1299-19f7-47d6-b58b-4d5bf09c55e9'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.74400329589844,
#    'Text': 'disciplines involves understanding the nature, prac-',
#    'BoundingBox': {'Width': 0.3385259807109833,
#     'Height': 0.012518475763499737,
#     'Left': 0.5472660660743713,
#     'Top': 0.8085659742355347},
#    'Id': '1913ba7a-4b9f-4a5b-9595-0a330c22dc34'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89582824707031,
#    'Text': 'agents. A number of applications exist which aim to support',
#    'BoundingBox': {'Width': 0.3766409754753113,
#     'Height': 0.012275553308427334,
#     'Left': 0.09470511227846146,
#     'Top': 0.823489248752594},
#    'Id': 'c7190d2b-7ba4-420c-9fb5-f2c31b1d44fb'},
#   {'BlockType': 'LINE',
#    'Confidnece': 96.98355102539062,
#    'Text': 'tice, and reliability of moral judgments. For instance,',
#    'BoundingBox': {'Width': 0.3379009962081909,
#     'Height': 0.012284834869205952,
#     'Left': 0.5475397109985352,
#     'Top': 0.8236789703369141},
#    'Id': '83a44874-5d94-469e-941b-08e1cc9c789c'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.7315902709961,
#    'Text': 'religious practice, such as the Roman Catholic Confession',
#    'BoundingBox': {'Width': 0.3763047754764557,
#     'Height': 0.01200149580836296,
#     'Left': 0.09494514018297195,
#     'Top': 0.8386013507843018},
#    'Id': 'f79ddb7d-51e5-4fbf-a449-4a45d3f6b0c0'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86426544189453,
#    'Text': 'an issue of perennial interest concerns what moral',
#    'BoundingBox': {'Width': 0.33807218074798584,
#     'Height': 0.012069725431501865,
#     'Left': 0.5471169948577881,
#     'Top': 0.8388684391975403},
#    'Id': 'b4b0c5ad-be98-4f73-b9b4-c778eaefbb71'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.1042709350586,
#    'Text': 'app (Rau 2011) and Muslim Pro which can tell you prayer',
#    'BoundingBox': {'Width': 0.3772521913051605,
#     'Height': 0.012276665307581425,
#     'Left': 0.09458192437887192,
#     'Top': 0.8538386821746826},
#    'Id': 'c256cdb6-d124-426a-8f06-cf9c4570867f'},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.03174591064453,
#    'Text': 'judgments are and how moral judgments differ from',
#    'BoundingBox': {'Width': 0.33862510323524475,
#     'Height': 0.012088406831026077,
#     'Left': 0.5465965270996094,
#     'Top': 0.854054868221283},
#    'Id': '0c626b44-3f39-4579-a8fa-282b9a3bd5e1'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.75271606445312,
#    'Text': 'times and the direction of Mecca in your own town or vil-',
#    'BoundingBox': {'Width': 0.3759530484676361,
#     'Height': 0.011976637877523899,
#     'Left': 0.09523768723011017,
#     'Top': 0.8688437938690186},
#    'Id': 'b6623081-2cfc-496c-a663-b1bfc6905d21'},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.83973693847656,
#    'Text': 'nonmoral judgments. Moral judgments such as "Tor-',
#    'BoundingBox': {'Width': 0.3379890024662018,
#     'Height': 0.012119278311729431,
#     'Left': 0.5473828911781311,
#     'Top': 0.8691571354866028},
#    'Id': '36f1a2d2-388a-4683-b2c5-1ae84a4b8438'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86360931396484,
#    'Text': 'lage (Muslim Pro 2019), and attempts have already been',
#    'BoundingBox': {'Width': 0.3766023516654968,
#     'Height': 0.012059930711984634,
#     'Left': 0.09455994516611099,
#     'Top': 0.8839313983917236},
#    'Id': 'd19894f1-dd8c-4d49-bbaf-583f329e284f'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78987121582031,
#    'Text': 'ture is wrong" seem different from nonmoral judg-',
#    'BoundingBox': {'Width': 0.33758899569511414,
#     'Height': 0.012482848949730396,
#     'Left': 0.5475397109985352,
#     'Top': 0.8841251134872437},
#    'Id': 'ecf2178c-3b20-4f9e-b74e-d507e7ab005a'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.83020782470703,
#    'Text': 'made to use robots in ritual. Most of the literature here is in',
#    'BoundingBox': {'Width': 0.3766321539878845,
#     'Height': 0.009464262053370476,
#     'Left': 0.09477835893630981,
#     'Top': 0.8991024494171143},
#    'Id': '202bac46-9d67-4466-bdf7-8b6a29cde060'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.10945892333984,
#    'Text': 'ments such as "Water is wet." But how do moral judg-',
#    'BoundingBox': {'Width': 0.3376505970954895,
#     'Height': 0.012195220217108727,
#     'Left': 0.5474132299423218,
#     'Top': 0.8994714617729187},
#    'Id': 'b7cdeb3a-3523-4ea2-a4ab-45240238c317'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.48381805419922,
#    'Text': 'popular journals and the press, SO it may be difficult to assess',
#    'BoundingBox': {'Width': 0.37633493542671204,
#     'Height': 0.011975080706179142,
#     'Left': 0.09481871128082275,
#     'Top': 0.9142476916313171},
#    'Id': '58691912-adae-4890-bc1e-170ada74060d'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.68680572509766,
#    'Text': 'ments differ from nonmoral, but normative judg-',
#    'BoundingBox': {'Width': 0.33801883459091187,
#     'Height': 0.012343087233603,
#     'Left': 0.5473271012306213,
#     'Top': 0.9145215153694153},
#    'Id': 'bf5a935f-8197-4f11-a168-b4bd7bc34788'}]}

# %%
df = pd.DataFrame(page)
df = df.join(pd.json_normalize(df["Blocks"].tolist()).add_prefix("Blocks.")).drop(["Blocks"], axis=1)
df.head(3)
# Out:
#    Page Blocks.BlockType  Blocks.Confidnece  \
# 0     1             LINE          99.913162
# 1     1             LINE          99.255280
# 2     1             LINE          99.461853
#
#                                          Blocks.Text  \
# 0                                                602
# 1                           Knowl. Org. 46(2019)No.8
# 2  V. Broughton. The Respective Roles of Intellec...
#
#                               Blocks.Id  Blocks.BoundingBox.Width  \
# 0  55217c52-606c-44c5-9e53-a177056dcec3                  0.021086
# 1  496002de-a71a-462c-a4be-84543ace97f4                  0.156732
# 2  b2a6c83f-390c-4afa-aa3e-aec08f1e6ffd                  0.610333
#
#    Blocks.BoundingBox.Height  Blocks.BoundingBox.Left  Blocks.BoundingBox.Top
# 0                   0.007798                 0.094833                0.068957
# 1                   0.011316                 0.748032                0.070955
# 2                   0.011693                 0.294765                0.086801

# %%
#top of the document = min of bounding box top
top = df['Blocks.BoundingBox.Top'].min()
top
# Out:
# 0.06895650923252106

# %%
#bottom of the document = max of bounding box top + height
df['Blocks.BoundingBox.Bottom'] = df['Blocks.BoundingBox.Top'] + df['Blocks.BoundingBox.Height']
bottom = df['Blocks.BoundingBox.Bottom'].max()
bottom
# Out:
# 0.9268646026030183

# %%
#midpoint vertical
v_midpoint = (bottom-top)/2
v_midpoint
# Out:
# 0.40344604663550854

# %%
#left of the document = min of bounding box left
left = df['Blocks.BoundingBox.Left'].min()
left
# Out:
# 0.0942993089556694

# %%
# right of the document = max of bounding box left + width
df['Blocks.BoundingBox.Right'] = df['Blocks.BoundingBox.Left'] + df['Blocks.BoundingBox.Width']
right = df['Blocks.BoundingBox.Right'].max()
right
# Out:
# 0.9051090180873871

# %%
#midpoint horizontal
h_midpoint = (right-left)/2
h_midpoint
# Out:
# 0.40540485456585884

# %%
#definitions 
# Q1 = top < v_midpoint and left < h_midpoint
# Q2 = top < v_midpoint and left > h_midpoint
# Q3 = top > v_midpoint and left < h_midpoint
# Q4 = top > v_midpoint and left > h_midpoint

# %%
def assign_quad(top, left):
    if top < v_midpoint and left < h_midpoint:
        return 'Q1'
    elif top < v_midpoint and left > h_midpoint:
        return 'Q2'
    elif top > v_midpoint and left < h_midpoint:
        return 'Q3'
    elif top > v_midpoint and left > h_midpoint:
        return 'Q4'

# %%
df['Quadrant'] = df.apply(lambda x: assign_quad(x['Blocks.BoundingBox.Top'], x['Blocks.BoundingBox.Left']), axis=1)
df.head(3)
# Out:
#    Page Blocks.BlockType  Blocks.Confidnece  \
# 0     1             LINE          99.913162
# 1     1             LINE          99.255280
# 2     1             LINE          99.461853
#
#                                          Blocks.Text  \
# 0                                                602
# 1                           Knowl. Org. 46(2019)No.8
# 2  V. Broughton. The Respective Roles of Intellec...
#
#                               Blocks.Id  Blocks.BoundingBox.Width  \
# 0  55217c52-606c-44c5-9e53-a177056dcec3                  0.021086
# 1  496002de-a71a-462c-a4be-84543ace97f4                  0.156732
# 2  b2a6c83f-390c-4afa-aa3e-aec08f1e6ffd                  0.610333
#
#    Blocks.BoundingBox.Height  Blocks.BoundingBox.Left  Blocks.BoundingBox.Top  \
# 0                   0.007798                 0.094833                0.068957
# 1                   0.011316                 0.748032                0.070955
# 2                   0.011693                 0.294765                0.086801
#
#    Blocks.BoundingBox.Bottom  Blocks.BoundingBox.Right Quadrant
# 0                   0.076754                  0.115918       Q1
# 1                   0.082271                  0.904763       Q2
# 2                   0.098494                  0.905098       Q1

# %%
df[df['Quadrant']=='Q2'][['Blocks.Text', 'Blocks.BoundingBox.Top']].sort_values(by=['Blocks.BoundingBox.Top'])
# Out:
#                                           Blocks.Text  Blocks.BoundingBox.Top
# 1                            Knowl. Org. 46(2019)No.8                0.070955
# 4   how serious these efforts are. We learn of a C...                0.129677
# 5   priest in Wittenberg which radiates light from...                0.144910
# 7   pronounces blessings in five languages as part...                0.159977
# 9   tion to celebrate 500 years since the inventio...                0.174802
# 11  technology, instrumental in the Reformation an...                0.190257
# 13  Protestantism (Sherwood 2017). Other cases inc...                0.205274
# 15  Buddhist monk in China (Tatlow 2016) which rea...                0.220308
# 17  ture and can answer questions, and another in ...                0.235644
# 19  2017) which can "chant prayers and tap drums a...                0.250584
# 21                                 funeral ceremony."                0.265764
# 23  There is also a literature in the overlap betw...                0.280747
# 25  philosophy and AI that considers the nature of...                0.295788
# 27  ships between intelligent agents, humans and t...                0.311023
# 29  God, typically whether the creation of intelli...                0.325747
# 31  some sense mirrors the creation of humans (Her...                0.341032
# 33  2003), and if the possibilities of transhumani...                0.355975
# 35  technological alteration of species are realiz...                0.371066
# 37  2017). Vidal (2007, 930) makes a comparison be...                0.386187
# 39  interaction with artificial beings and his int...                0.401362

# %%
df_q4 = df[df['Quadrant']=='Q4'].sort_values(by=['Blocks.BoundingBox.Top'])
df_q4.head(3)
# Out:
#     Page Blocks.BlockType  Blocks.Confidnece  \
# 38     1             LINE          99.740250
# 40     1             LINE          99.961006
# 42     1             LINE          99.825294
#
#                                           Blocks.Text  \
# 38   Hartmann (1964), presuppose and build themselves
# 40  upon each other, and which can be specified ea...
# 42                                 nine aspect areas.
#
#                                Blocks.Id  Blocks.BoundingBox.Width  \
# 38  8992ea29-905e-453c-aa43-110052895bc3                  0.333041
# 40  81985e80-b3fb-4cdb-9779-8ba91d6959ca                  0.333973
# 42  ab821410-50d1-4ea8-aeeb-7a6138791967                  0.107659
#
#     Blocks.BoundingBox.Height  Blocks.BoundingBox.Left  \
# 38                   0.012868                 0.525323
# 40                   0.012577                 0.525128
# 42                   0.011704                 0.524958
#
#     Blocks.BoundingBox.Top  Blocks.BoundingBox.Bottom  \
# 38                0.404565                   0.417433
# 40                0.419564                   0.432142
# 42                0.434916                   0.446620
#
#     Blocks.BoundingBox.Right Quadrant
# 38                  0.858364       Q4
# 40                  0.859101       Q4
# 42                  0.632617       Q4

# %%
json_4 = df_q4.to_json(orient='records')
parsed = json.loads(json_4)
parsed
# Out:
# [{'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7402496338,
#   'Blocks.Text': 'Hartmann (1964), presuppose and build themselves',
#   'Blocks.Id': '8992ea29-905e-453c-aa43-110052895bc3',
#   'Blocks.BoundingBox.Width': 0.3330409825,
#   'Blocks.BoundingBox.Height': 0.0128680039,
#   'Blocks.BoundingBox.Left': 0.5253229141,
#   'Blocks.BoundingBox.Top': 0.4045654833,
#   'Blocks.BoundingBox.Bottom': 0.4174334873,
#   'Blocks.BoundingBox.Right': 0.8583638966,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9610061646,
#   'Blocks.Text': 'upon each other, and which can be specified each by',
#   'Blocks.Id': '81985e80-b3fb-4cdb-9779-8ba91d6959ca',
#   'Blocks.BoundingBox.Width': 0.3339730799,
#   'Blocks.BoundingBox.Height': 0.0125774248,
#   'Blocks.BoundingBox.Left': 0.5251280665,
#   'Blocks.BoundingBox.Top': 0.4195641279,
#   'Blocks.BoundingBox.Bottom': 0.4321415527,
#   'Blocks.BoundingBox.Right': 0.8591011465,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8252944946,
#   'Blocks.Text': 'nine aspect areas.',
#   'Blocks.Id': 'ab821410-50d1-4ea8-aeeb-7a6138791967',
#   'Blocks.BoundingBox.Width': 0.1076590791,
#   'Blocks.BoundingBox.Height': 0.0117039466,
#   'Blocks.BoundingBox.Left': 0.5249583721,
#   'Blocks.BoundingBox.Top': 0.4349156618,
#   'Blocks.BoundingBox.Bottom': 0.4466196084,
#   'Blocks.BoundingBox.Right': 0.6326174513,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.6709289551,
#   'Blocks.Text': 'Looking at Figure 2, demonstrating these nine ar-',
#   'Blocks.Id': '3a087a0a-648d-48a8-8dfc-79b16b26c684',
#   'Blocks.BoundingBox.Width': 0.3166174591,
#   'Blocks.BoundingBox.Height': 0.0128099928,
#   'Blocks.BoundingBox.Left': 0.5420069098,
#   'Blocks.BoundingBox.Top': 0.4487785697,
#   'Blocks.BoundingBox.Bottom': 0.4615885625,
#   'Blocks.BoundingBox.Right': 0.8586243689,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8458480835,
#   'Blocks.Text': 'eas of being, it is obvious that area 8 is the one deal-',
#   'Blocks.Id': 'cdb61af6-3c1e-4abb-b19e-c1416510bbfb',
#   'Blocks.BoundingBox.Width': 0.3334934413,
#   'Blocks.BoundingBox.Height': 0.0130273141,
#   'Blocks.BoundingBox.Left': 0.5253400803,
#   'Blocks.BoundingBox.Top': 0.4635015428,
#   'Blocks.BoundingBox.Bottom': 0.4765288569,
#   'Blocks.BoundingBox.Right': 0.8588335216,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.920539856,
#   'Blocks.Text': 'ing with the intellectual products of man and society,',
#   'Blocks.Id': '6936904e-d441-43c5-a541-4c3394ef2bcc',
#   'Blocks.BoundingBox.Width': 0.3337215185,
#   'Blocks.BoundingBox.Height': 0.0128708947,
#   'Blocks.BoundingBox.Left': 0.5250607133,
#   'Blocks.BoundingBox.Top': 0.4781041741,
#   'Blocks.BoundingBox.Bottom': 0.4909750689,
#   'Blocks.BoundingBox.Right': 0.8587822318,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.4521255493,
#   'Blocks.Text': 'which means "knowledge" and "information." In the',
#   'Blocks.Id': '2f9da1a6-f119-4496-b057-1c076ccf60ee',
#   'Blocks.BoundingBox.Width': 0.3337815106,
#   'Blocks.BoundingBox.Height': 0.0127396816,
#   'Blocks.BoundingBox.Left': 0.5251071453,
#   'Blocks.BoundingBox.Top': 0.4930077195,
#   'Blocks.BoundingBox.Bottom': 0.5057474012,
#   'Blocks.BoundingBox.Right': 0.8588886559,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7719802856,
#   'Blocks.Text': 'presentation of the matrix it can be seen that under 1',
#   'Blocks.Id': 'bfdb4170-dff8-4e0b-a252-25c076f9730f',
#   'Blocks.BoundingBox.Width': 0.3330686092,
#   'Blocks.BoundingBox.Height': 0.0126615576,
#   'Blocks.BoundingBox.Left': 0.5247623324,
#   'Blocks.BoundingBox.Top': 0.5075548887,
#   'Blocks.BoundingBox.Bottom': 0.5202164464,
#   'Blocks.BoundingBox.Right': 0.8578309417,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9220504761,
#   'Blocks.Text': 'always the general and theoretical aspects of an object',
#   'Blocks.Id': 'f403e707-bde7-47b2-89b4-a07459117af2',
#   'Blocks.BoundingBox.Width': 0.3335679471,
#   'Blocks.BoundingBox.Height': 0.0127758542,
#   'Blocks.BoundingBox.Left': 0.5250982642,
#   'Blocks.BoundingBox.Top': 0.5223276615,
#   'Blocks.BoundingBox.Bottom': 0.5351035157,
#   'Blocks.BoundingBox.Right': 0.8586662114,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8580474854,
#   'Blocks.Text': 'area are apprehended, which, in the case of area 8,',
#   'Blocks.Id': '7b5d79dd-1085-4f78-b77e-0f05b95d11c4',
#   'Blocks.BoundingBox.Width': 0.3334122598,
#   'Blocks.BoundingBox.Height': 0.0124764675,
#   'Blocks.BoundingBox.Left': 0.525006175,
#   'Blocks.BoundingBox.Top': 0.536919713,
#   'Blocks.BoundingBox.Bottom': 0.5493961805,
#   'Blocks.BoundingBox.Right': 0.8584184349,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.6429519653,
#   'Blocks.Text': 'must be "Science of Science." Its subdivisions are',
#   'Blocks.Id': '18eca666-d8ec-4731-af29-0f92b49eedda',
#   'Blocks.BoundingBox.Width': 0.3335680664,
#   'Blocks.BoundingBox.Height': 0.0101276906,
#   'Blocks.BoundingBox.Left': 0.5251809359,
#   'Blocks.BoundingBox.Top': 0.5518020391,
#   'Blocks.BoundingBox.Bottom': 0.5619297298,
#   'Blocks.BoundingBox.Right': 0.8587490022,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.752746582,
#   'Blocks.Text': 'then, i.a., Theory of science, History of science, Sci-',
#   'Blocks.Id': '7618690f-b92a-42ca-b0ce-70e3ec907478',
#   'Blocks.BoundingBox.Width': 0.3337626457,
#   'Blocks.BoundingBox.Height': 0.0125727775,
#   'Blocks.BoundingBox.Left': 0.5248525143,
#   'Blocks.BoundingBox.Top': 0.5666262507,
#   'Blocks.BoundingBox.Bottom': 0.5791990282,
#   'Blocks.BoundingBox.Right': 0.85861516,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7351074219,
#   'Blocks.Text': 'ence research, etc. In the ontical area 1, the area of',
#   'Blocks.Id': '78fa9239-5906-4681-ae8a-95995f8ea4a6',
#   'Blocks.BoundingBox.Width': 0.3343920112,
#   'Blocks.BoundingBox.Height': 0.0114744194,
#   'Blocks.BoundingBox.Left': 0.5253630877,
#   'Blocks.BoundingBox.Top': 0.5813298225,
#   'Blocks.BoundingBox.Bottom': 0.5928042419,
#   'Blocks.BoundingBox.Right': 0.8597550988,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.874458313,
#   'Blocks.Text': 'Form and Structure, one will find the System Sciences',
#   'Blocks.Id': '1c977777-5ff4-40ce-9af8-f33cbf6bf613',
#   'Blocks.BoundingBox.Width': 0.3336678743,
#   'Blocks.BoundingBox.Height': 0.0124309175,
#   'Blocks.BoundingBox.Left': 0.5251202583,
#   'Blocks.BoundingBox.Top': 0.596093297,
#   'Blocks.BoundingBox.Bottom': 0.6085242145,
#   'Blocks.BoundingBox.Right': 0.8587881327,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8528366089,
#   'Blocks.Text': 'at the position 4 as a specialty of form and structure.',
#   'Blocks.Id': '3779e59c-d011-4d75-aa6d-5256c14bb0d8',
#   'Blocks.BoundingBox.Width': 0.3337365687,
#   'Blocks.BoundingBox.Height': 0.01268321,
#   'Blocks.BoundingBox.Left': 0.5249855518,
#   'Blocks.BoundingBox.Top': 0.6106983423,
#   'Blocks.BoundingBox.Bottom': 0.6233815523,
#   'Blocks.BoundingBox.Right': 0.8587221205,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9302597046,
#   'Blocks.Text': 'Therefore it seemed logical for me regarding the sys-',
#   'Blocks.Id': '65904d7b-7c64-4d4c-86e3-67afa8add77e',
#   'Blocks.BoundingBox.Width': 0.3339411616,
#   'Blocks.BoundingBox.Height': 0.0128018437,
#   'Blocks.BoundingBox.Left': 0.5246158838,
#   'Blocks.BoundingBox.Top': 0.6254956722,
#   'Blocks.BoundingBox.Bottom': 0.6382975159,
#   'Blocks.BoundingBox.Right': 0.8585570455,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7610778809,
#   'Blocks.Text': 'tem character of knowledge, as every knowledge unit',
#   'Blocks.Id': '98f217a2-1056-43ca-867e-96f9c0d9d3ca',
#   'Blocks.BoundingBox.Width': 0.3334323466,
#   'Blocks.BoundingBox.Height': 0.0126919886,
#   'Blocks.BoundingBox.Left': 0.525262177,
#   'Blocks.BoundingBox.Top': 0.6400042176,
#   'Blocks.BoundingBox.Bottom': 0.6526962062,
#   'Blocks.BoundingBox.Right': 0.8586945236,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8336181641,
#   'Blocks.Text': 'is related to another one by its concept characteris-',
#   'Blocks.Id': '35489b64-113b-4d3c-88a8-c4de1189765f',
#   'Blocks.BoundingBox.Width': 0.3335147202,
#   'Blocks.BoundingBox.Height': 0.0124204522,
#   'Blocks.BoundingBox.Left': 0.5250869393,
#   'Blocks.BoundingBox.Top': 0.6549850702,
#   'Blocks.BoundingBox.Bottom': 0.6674055224,
#   'Blocks.BoundingBox.Right': 0.8586016595,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8981246948,
#   'Blocks.Text': 'tics, to place knowledge organization at position 4 of',
#   'Blocks.Id': 'ecdee2c9-c17c-4c08-9abd-c7916e069f52',
#   'Blocks.BoundingBox.Width': 0.3346248567,
#   'Blocks.BoundingBox.Height': 0.0128761511,
#   'Blocks.BoundingBox.Left': 0.525287807,
#   'Blocks.BoundingBox.Top': 0.6697197556,
#   'Blocks.BoundingBox.Bottom': 0.6825959068,
#   'Blocks.BoundingBox.Right': 0.8599126637,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8679962158,
#   'Blocks.Text': 'science of science under 81, thus 814.',
#   'Blocks.Id': 'b55348c4-e8b7-434d-a55f-df178d04e3b8',
#   'Blocks.BoundingBox.Width': 0.2303113043,
#   'Blocks.BoundingBox.Height': 0.0113396393,
#   'Blocks.BoundingBox.Left': 0.5252761245,
#   'Blocks.BoundingBox.Top': 0.6843425035,
#   'Blocks.BoundingBox.Bottom': 0.6956821429,
#   'Blocks.BoundingBox.Right': 0.7555874288,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8720779419,
#   'Blocks.Text': 'This should be regarded as a proposition only,',
#   'Blocks.Id': 'd4540dc6-3a1c-4fe8-84cd-b1a28265b994',
#   'Blocks.BoundingBox.Width': 0.317140907,
#   'Blocks.BoundingBox.Height': 0.0129391029,
#   'Blocks.BoundingBox.Left': 0.5414869189,
#   'Blocks.BoundingBox.Top': 0.6989313364,
#   'Blocks.BoundingBox.Bottom': 0.7118704394,
#   'Blocks.BoundingBox.Right': 0.858627826,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9085235596,
#   'Blocks.Text': 'along with the entire system of knowledge fields, as',
#   'Blocks.Id': 'b53bfb3c-437f-49e1-ad17-b4409445c018',
#   'Blocks.BoundingBox.Width': 0.3335577548,
#   'Blocks.BoundingBox.Height': 0.0128442841,
#   'Blocks.BoundingBox.Left': 0.5249180198,
#   'Blocks.BoundingBox.Top': 0.7135606408,
#   'Blocks.BoundingBox.Bottom': 0.7264049249,
#   'Blocks.BoundingBox.Right': 0.8584757745,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9371948242,
#   'Blocks.Text': 'represented by this universal classification system,',
#   'Blocks.Id': '51d19172-f5d8-499a-869c-2d0a9c299d5b',
#   'Blocks.BoundingBox.Width': 0.3335114419,
#   'Blocks.BoundingBox.Height': 0.0125873089,
#   'Blocks.BoundingBox.Left': 0.5250533223,
#   'Blocks.BoundingBox.Top': 0.7284932137,
#   'Blocks.BoundingBox.Bottom': 0.7410805225,
#   'Blocks.BoundingBox.Right': 0.8585647643,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9517364502,
#   'Blocks.Text': 'under which nearly 7000 concepts of knowledge or',
#   'Blocks.Id': '5caec02a-0723-447d-8bf3-256afd8a5916',
#   'Blocks.BoundingBox.Width': 0.3343520164,
#   'Blocks.BoundingBox.Height': 0.012896901,
#   'Blocks.BoundingBox.Left': 0.5249406695,
#   'Blocks.BoundingBox.Top': 0.7429337502,
#   'Blocks.BoundingBox.Bottom': 0.7558306511,
#   'Blocks.BoundingBox.Right': 0.859292686,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8725738525,
#   'Blocks.Text': 'subject fields (and not as yet their contents) on a',
#   'Blocks.Id': '65396079-4f84-42f5-994f-acc608bb0b01',
#   'Blocks.BoundingBox.Width': 0.3336289227,
#   'Blocks.BoundingBox.Height': 0.0128115788,
#   'Blocks.BoundingBox.Left': 0.5253269672,
#   'Blocks.BoundingBox.Top': 0.7577353716,
#   'Blocks.BoundingBox.Bottom': 0.7705469504,
#   'Blocks.BoundingBox.Right': 0.8589558899,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8807678223,
#   'Blocks.Text': 'number of subdivisional levels were elaborated on',
#   'Blocks.Id': '74f0c6ab-4298-44f4-b98b-2dec7c7c80e4',
#   'Blocks.BoundingBox.Width': 0.3334522545,
#   'Blocks.BoundingBox.Height': 0.0103342896,
#   'Blocks.BoundingBox.Left': 0.5252485275,
#   'Blocks.BoundingBox.Top': 0.7724868059,
#   'Blocks.BoundingBox.Bottom': 0.7828210955,
#   'Blocks.BoundingBox.Right': 0.8587007821,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9068527222,
#   'Blocks.Text': 'the basis of their definitions. (The definitions were',
#   'Blocks.Id': 'c980fee8-5295-4f0a-8b4d-a5fc1ae82da9',
#   'Blocks.BoundingBox.Width': 0.3336918354,
#   'Blocks.BoundingBox.Height': 0.0125924284,
#   'Blocks.BoundingBox.Left': 0.5250143409,
#   'Blocks.BoundingBox.Top': 0.7871433496,
#   'Blocks.BoundingBox.Bottom': 0.799735778,
#   'Blocks.BoundingBox.Right': 0.8587061763,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.2441482544,
#   'Blocks.Text': 'taken from encyclopedias, from Wahrig (1975), and',
#   'Blocks.Id': 'dbaf87bf-b14d-4851-9533-0f9a94a762f7',
#   'Blocks.BoundingBox.Width': 0.3334186375,
#   'Blocks.BoundingBox.Height': 0.0126461983,
#   'Blocks.BoundingBox.Left': 0.5253139138,
#   'Blocks.BoundingBox.Top': 0.8020603657,
#   'Blocks.BoundingBox.Bottom': 0.8147065639,
#   'Blocks.BoundingBox.Right': 0.8587325513,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7355194092,
#   'Blocks.Text': 'from 500 special dictionaries. They were discussed',
#   'Blocks.Id': '8124a8ba-fdeb-4c09-a074-724529806ce7',
#   'Blocks.BoundingBox.Width': 0.3333893716,
#   'Blocks.BoundingBox.Height': 0.0126707582,
#   'Blocks.BoundingBox.Left': 0.5252820849,
#   'Blocks.BoundingBox.Top': 0.8165684342,
#   'Blocks.BoundingBox.Bottom': 0.8292391924,
#   'Blocks.BoundingBox.Right': 0.8586714566,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9408798218,
#   'Blocks.Text': 'with almost 300 university teachers. In this sense it',
#   'Blocks.Id': '59991267-bf57-4789-a72e-b3592facbb19',
#   'Blocks.BoundingBox.Width': 0.3338460326,
#   'Blocks.BoundingBox.Height': 0.0124213751,
#   'Blocks.BoundingBox.Left': 0.5249839425,
#   'Blocks.BoundingBox.Top': 0.8316065669,
#   'Blocks.BoundingBox.Bottom': 0.844027942,
#   'Blocks.BoundingBox.Right': 0.8588299751,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.8979187012,
#   'Blocks.Text': "forms, expressed in today's pertinent terminology,",
#   'Blocks.Id': '6240be9a-afbb-4f5a-b718-b78f4e428549',
#   'Blocks.BoundingBox.Width': 0.3332333863,
#   'Blocks.BoundingBox.Height': 0.0128007503,
#   'Blocks.BoundingBox.Left': 0.5252733827,
#   'Blocks.BoundingBox.Top': 0.8460962772,
#   'Blocks.BoundingBox.Bottom': 0.8588970276,
#   'Blocks.BoundingBox.Right': 0.8585067689,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.7045440674,
#   'Blocks.Text': 'an "upper ontology.") The system could well be used',
#   'Blocks.Id': '782a277d-d1fd-42e7-a050-bbb007196b9d',
#   'Blocks.BoundingBox.Width': 0.3338077366,
#   'Blocks.BoundingBox.Height': 0.0126979221,
#   'Blocks.BoundingBox.Left': 0.5250379443,
#   'Blocks.BoundingBox.Top': 0.8610162735,
#   'Blocks.BoundingBox.Bottom': 0.8737141956,
#   'Blocks.BoundingBox.Right': 0.858845681,
#   'Quadrant': 'Q4'},
#  {'Page': 1,
#   'Blocks.BlockType': 'LINE',
#   'Blocks.Confidnece': 99.9319763184,
#   'Blocks.Text': 'for the purpose mentioned in the next chapter, but it',
#   'Blocks.Id': 'df1d0b92-20cc-4b89-a3ff-f12105da85fb',
#   'Blocks.BoundingBox.Width': 0.3333208263,
#   'Blocks.BoundingBox.Height': 0.0125344871,
#   'Blocks.BoundingBox.Left': 0.5252566338,
#   'Blocks.BoundingBox.Top': 0.8759285808,
#   'Blocks.BoundingBox.Bottom': 0.8884630678,
#   'Blocks.BoundingBox.Right': 0.8585774601,
#   'Quadrant': 'Q4'}]

# %%
for idx, block in enumerate(page['Blocks']):
    if block['BoundingBox']['Top'] < v_midpoint and block['BoundingBox']['Left'] < h_midpoint:
        block['Quadrant'] = 'Q1'
    elif block['BoundingBox']['Top'] < v_midpoint and block['BoundingBox']['Left'] > h_midpoint:
        block['Quadrant'] = 'Q2'
    elif block['BoundingBox']['Top'] > v_midpoint and block['BoundingBox']['Left'] < h_midpoint:
        block['Quadrant'] = 'Q3'
    elif block['BoundingBox']['Top'] > v_midpoint and block['BoundingBox']['Left'] > h_midpoint:
        block['Quadrant'] = 'Q4'

# %%
core_q4 = [x for x in page['Blocks'] if x['Quadrant'] in ['Q4']]
core_q4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jhirt\OneDrive - UWM\PhD\Fall 2023\INFOST 910-001\Final Project\T2 Model Test Script.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jhirt/OneDrive%20-%20UWM/PhD/Fall%202023/INFOST%20910-001/Final%20Project/T2%20Model%20Test%20Script.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> core_q4 = [x for x in page['Blocks'] if x['Quadrant'] in ['Q4']]
#       <a href='vscode-notebook-cell:/c%3A/Users/jhirt/OneDrive%20-%20UWM/PhD/Fall%202023/INFOST%20910-001/Final%20Project/T2%20Model%20Test%20Script.ipynb#X30sZmlsZQ%3D%3D?line=1'>2</a> core_q4
#
# NameError: name 'page' is not defined

# %%
#test Q4
core = page['Blocks']
# core_q4 = [x for x in core if x['Quadrant'] in ['Q4', 'Q2']]
core_q4 = [x for x in core if x['Quadrant'] in ['Q4']]
# core_q4

page_q4 = page.copy()
page_q4['Blocks'] = core_q4
page_q4
# Out:
# {'Page': 1,
#  'Blocks': [{'BlockType': 'LINE',
#    'Confidnece': 99.88965606689453,
#    'Text': 'gods, asking whether the similarities are not caused by un-',
#    'BoundingBox': {'Width': 0.3763725757598877,
#     'Height': 0.01213967613875866,
#     'Left': 0.5279744267463684,
#     'Top': 0.41641929745674133},
#    'Id': 'a4fbb4e5-236a-43e3-a454-5e929fc0eedc',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.810302734375,
#    'Text': 'certainty:',
#    'BoundingBox': {'Width': 0.057482946664094925,
#     'Height': 0.011118726804852486,
#     'Left': 0.5284923315048218,
#     'Top': 0.4321962594985962},
#    'Id': 'e46693fa-2f33-4a11-8475-6a9c82651bf4',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93927764892578,
#    'Text': 'But it is also true that where interaction is supposed',
#    'BoundingBox': {'Width': 0.33780840039253235,
#     'Height': 0.011987521313130856,
#     'Left': 0.5472887754440308,
#     'Top': 0.46187761425971985},
#    'Id': 'bb137a9b-9631-4835-8b44-3e72ca66f830',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88581085205078,
#    'Text': 'to exist between the gods and their worshippers,',
#    'BoundingBox': {'Width': 0.33762651681900024,
#     'Height': 0.01210279855877161,
#     'Left': 0.5474798083305359,
#     'Top': 0.47703441977500916},
#    'Id': 'd3e81fdd-96a2-4887-994f-d754a0d182b1',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89601135253906,
#    'Text': 'there always remains a strong element of uncertainty',
#    'BoundingBox': {'Width': 0.3383662700653076,
#     'Height': 0.012020442634820938,
#     'Left': 0.547386646270752,
#     'Top': 0.49205300211906433},
#    'Id': '569bd288-d864-4b73-9574-2636f50e450b',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88188171386719,
#    'Text': 'which cannot easily be dismissed concerning the ex-',
#    'BoundingBox': {'Width': 0.3381541073322296,
#     'Height': 0.012135365977883339,
#     'Left': 0.5470730662345886,
#     'Top': 0.5070592164993286},
#    'Id': '187e704a-4997-4d2f-b84e-75094726fd60',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88674926757812,
#    'Text': 'act ontological nature of the hybrid arrangement by',
#    'BoundingBox': {'Width': 0.3383806049823761,
#     'Height': 0.012129907496273518,
#     'Left': 0.547204315662384,
#     'Top': 0.5221974849700928},
#    'Id': '747fb7ec-5db4-4b21-b6ca-bb65fc73bb1d',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8985366821289,
#    'Text': "which the divinity's presence is made manifest. It is",
#    'BoundingBox': {'Width': 0.338032066822052,
#     'Height': 0.012063227593898773,
#     'Left': 0.5471490025520325,
#     'Top': 0.5371823906898499},
#    'Id': 'b8cc6f1a-d9a2-46a3-8953-f059377923f5',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8282470703125,
#    'Text': 'precisely the same sort of ontological uncertainty',
#    'BoundingBox': {'Width': 0.33800628781318665,
#     'Height': 0.01202689204365015,
#     'Left': 0.5473697781562805,
#     'Top': 0.5521544814109802},
#    'Id': '38163439-f99a-4472-88ba-c8e105077a48',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6975326538086,
#    'Text': 'that one finds expressed in the field of robotics. And',
#    'BoundingBox': {'Width': 0.3379596471786499,
#     'Height': 0.011985193006694317,
#     'Left': 0.5473806858062744,
#     'Top': 0.5671889185905457},
#    'Id': 'fa2eed48-83f4-4ecc-ac49-25f8f18f6ad5',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.9035415649414,
#    'Text': 'this is also why robots both fascinate and worry the',
#    'BoundingBox': {'Width': 0.3379111588001251,
#     'Height': 0.012089177034795284,
#     'Left': 0.5474206209182739,
#     'Top': 0.5822350978851318},
#    'Id': 'e18f9094-33d7-4af4-9ea0-4d45cb6ae7d3',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.52567291259766,
#    'Text': 'general public.',
#    'BoundingBox': {'Width': 0.09428026527166367,
#     'Height': 0.01173343975096941,
#     'Left': 0.5468749403953552,
#     'Top': 0.5977197289466858},
#    'Id': 'a5e76928-75e7-4a6f-a0b9-2d2d16e3c15f',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93135070800781,
#    'Text': '6.2 The moral and religious life of machines',
#    'BoundingBox': {'Width': 0.31428366899490356,
#     'Height': 0.012095442041754723,
#     'Left': 0.528290331363678,
#     'Top': 0.6275264024734497},
#    'Id': 'f1f85e6a-975e-400a-8c33-fa0e77cc06e1',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92827606201172,
#    'Text': 'A pressing question is whether a real sense of moral re-',
#    'BoundingBox': {'Width': 0.3759782314300537,
#     'Height': 0.011910981498658657,
#     'Left': 0.5281528234481812,
#     'Top': 0.658055305480957},
#    'Id': 'f7bfe5d9-ca5b-4e12-b2af-499a831edef2',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84795379638672,
#    'Text': 'sponsibility can be developed in intelligent agents, or, more',
#    'BoundingBox': {'Width': 0.37622520327568054,
#     'Height': 0.012142231687903404,
#     'Left': 0.5284137725830078,
#     'Top': 0.6730008721351624},
#    'Id': 'a787c10a-6d38-4bf1-bbef-a7c6cceff271',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84844970703125,
#    'Text': 'fancifully perhaps, a proper religious sense. In human be-',
#    'BoundingBox': {'Width': 0.37574225664138794,
#     'Height': 0.012300929985940456,
#     'Left': 0.5284615159034729,
#     'Top': 0.6879498362541199},
#    'Id': '898ffb43-ff69-4ec8-8448-b5e21cf00004',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88512420654297,
#    'Text': 'ings, it may seem obvious that ethical decisions differ in',
#    'BoundingBox': {'Width': 0.37620705366134644,
#     'Height': 0.01185592357069254,
#     'Left': 0.528139054775238,
#     'Top': 0.703192412853241},
#    'Id': '5ba7a8ea-6929-40e8-8733-1bf0087ef783',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.75194549560547,
#    'Text': 'some significant respect from other kinds of decisions,',
#    'BoundingBox': {'Width': 0.37599822878837585,
#     'Height': 0.012068712152540684,
#     'Left': 0.5284170508384705,
#     'Top': 0.7182764410972595},
#    'Id': '0edfaccf-4dae-458a-9c1e-8238458ef448',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87187957763672,
#    'Text': 'and that intellectual reasoning is subordinate to, or at least',
#    'BoundingBox': {'Width': 0.3768402636051178,
#     'Height': 0.012221094220876694,
#     'Left': 0.5278121829032898,
#     'Top': 0.7333305478096008},
#    'Id': '31797f24-f90e-4333-897d-7ac28e5c273a',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6059799194336,
#    'Text': 'strongly influenced by, emotional intelligence. As Liao',
#    'BoundingBox': {'Width': 0.3757619857788086,
#     'Height': 0.01217692531645298,
#     'Left': 0.5282239317893982,
#     'Top': 0.7484709620475769},
#    'Id': '15601a1d-0c5c-48d7-a3a3-c29dfd29d8a9',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92679595947266,
#    'Text': '(2016) says:',
#    'BoundingBox': {'Width': 0.0738762766122818,
#     'Height': 0.011374508030712605,
#     'Left': 0.5288876891136169,
#     'Top': 0.7640493512153625},
#    'Id': 'f6e18ead-1b37-4afe-b891-6f68b584807a',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89524841308594,
#    'Text': 'Central area of intellectual inquiry across different',
#    'BoundingBox': {'Width': 0.3381929397583008,
#     'Height': 0.01220998540520668,
#     'Left': 0.547482430934906,
#     'Top': 0.7935547232627869},
#    'Id': '8baa7693-76e9-4f75-a733-33de904e82b9',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.74400329589844,
#    'Text': 'disciplines involves understanding the nature, prac-',
#    'BoundingBox': {'Width': 0.3385259807109833,
#     'Height': 0.012518475763499737,
#     'Left': 0.5472660660743713,
#     'Top': 0.8085659742355347},
#    'Id': '1913ba7a-4b9f-4a5b-9595-0a330c22dc34',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 96.98355102539062,
#    'Text': 'tice, and reliability of moral judgments. For instance,',
#    'BoundingBox': {'Width': 0.3379009962081909,
#     'Height': 0.012284834869205952,
#     'Left': 0.5475397109985352,
#     'Top': 0.8236789703369141},
#    'Id': '83a44874-5d94-469e-941b-08e1cc9c789c',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86426544189453,
#    'Text': 'an issue of perennial interest concerns what moral',
#    'BoundingBox': {'Width': 0.33807218074798584,
#     'Height': 0.012069725431501865,
#     'Left': 0.5471169948577881,
#     'Top': 0.8388684391975403},
#    'Id': 'b4b0c5ad-be98-4f73-b9b4-c778eaefbb71',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.03174591064453,
#    'Text': 'judgments are and how moral judgments differ from',
#    'BoundingBox': {'Width': 0.33862510323524475,
#     'Height': 0.012088406831026077,
#     'Left': 0.5465965270996094,
#     'Top': 0.854054868221283},
#    'Id': '0c626b44-3f39-4579-a8fa-282b9a3bd5e1',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.83973693847656,
#    'Text': 'nonmoral judgments. Moral judgments such as "Tor-',
#    'BoundingBox': {'Width': 0.3379890024662018,
#     'Height': 0.012119278311729431,
#     'Left': 0.5473828911781311,
#     'Top': 0.8691571354866028},
#    'Id': '36f1a2d2-388a-4683-b2c5-1ae84a4b8438',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78987121582031,
#    'Text': 'ture is wrong" seem different from nonmoral judg-',
#    'BoundingBox': {'Width': 0.33758899569511414,
#     'Height': 0.012482848949730396,
#     'Left': 0.5475397109985352,
#     'Top': 0.8841251134872437},
#    'Id': 'ecf2178c-3b20-4f9e-b74e-d507e7ab005a',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.10945892333984,
#    'Text': 'ments such as "Water is wet." But how do moral judg-',
#    'BoundingBox': {'Width': 0.3376505970954895,
#     'Height': 0.012195220217108727,
#     'Left': 0.5474132299423218,
#     'Top': 0.8994714617729187},
#    'Id': 'b7cdeb3a-3523-4ea2-a4ab-45240238c317',
#    'Quadrant': 'Q4'},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.68680572509766,
#    'Text': 'ments differ from nonmoral, but normative judg-',
#    'BoundingBox': {'Width': 0.33801883459091187,
#     'Height': 0.012343087233603,
#     'Left': 0.5473271012306213,
#     'Top': 0.9145215153694153},
#    'Id': 'bf5a935f-8197-4f11-a168-b4bd7bc34788',
#    'Quadrant': 'Q4'}]}

# %%
height_diff_above_json = append_height_diff_above(page_q4)
height_diff_below_json = append_height_diff_below(height_diff_above_json)
paragraph_number_json = append_paragraph_number(height_diff_below_json)
pg_num_std_json = append_paragraph_number_std(paragraph_number_json)
scaled_json = append_scaled(pg_num_std_json)
clustered_json = append_cluster(scaled_json)
clustered_json
# Out:
# {'Page': 1,
#  'Blocks': [{'BlockType': 'LINE',
#    'Confidnece': 99.88965606689453,
#    'Text': 'gods, asking whether the similarities are not caused by un-',
#    'BoundingBox': {'Width': 0.3763725757598877,
#     'Height': 0.01213967613875866,
#     'Left': 0.5279744267463684,
#     'Top': 0.41641929745674133},
#    'Id': 'a4fbb4e5-236a-43e3-a454-5e929fc0eedc',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0,
#    'height_diff_below': 0.003637285903096199,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.0,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.008224235813798941,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 0,
#    'cluster_probability': 0.054422199999495796},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.810302734375,
#    'Text': 'certainty:',
#    'BoundingBox': {'Width': 0.057482946664094925,
#     'Height': 0.011118726804852486,
#     'Left': 0.5284923315048218,
#     'Top': 0.4321962594985962},
#    'Id': 'e46693fa-2f33-4a11-8475-6a9c82651bf4',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.003637285903096199,
#    'height_diff_below': 0.01856262795627117,
#    'paragraph': 0,
#    'paragraph_std': 0,
#    'top_scl': 0.03167414533500601,
#    'paragraph_scl': 0.0,
#    'left_scl': 0.03447713257576979,
#    'paragraph_std_scl': 0.0,
#    'text_cluster': 0,
#    'cluster_probability': 0.05620764868979536},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93927764892578,
#    'Text': 'But it is also true that where interaction is supposed',
#    'BoundingBox': {'Width': 0.33780840039253235,
#     'Height': 0.011987521313130856,
#     'Left': 0.5472887754440308,
#     'Top': 0.46187761425971985},
#    'Id': 'bb137a9b-9631-4835-8b44-3e72ca66f830',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.01856262795627117,
#    'height_diff_below': 0.003169284202158451,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.09126302828659183,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9872799291785128,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 0.6146498412161469},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88581085205078,
#    'Text': 'to exist between the gods and their worshippers,',
#    'BoundingBox': {'Width': 0.33762651681900024,
#     'Height': 0.01210279855877161,
#     'Left': 0.5474798083305359,
#     'Top': 0.47703441977500916},
#    'Id': 'd3e81fdd-96a2-4887-994f-d754a0d182b1',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.003169284202158451,
#    'height_diff_below': 0.0029157837852835655,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.121692134944267,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9969634985331126,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89601135253906,
#    'Text': 'there always remains a strong element of uncertainty',
#    'BoundingBox': {'Width': 0.3383662700653076,
#     'Height': 0.012020442634820938,
#     'Left': 0.547386646270752,
#     'Top': 0.49205300211906433},
#    'Id': '569bd288-d864-4b73-9574-2636f50e450b',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0029157837852835655,
#    'height_diff_below': 0.002985771745443344,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.15184374199189554,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9922410589383439,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88188171386719,
#    'Text': 'which cannot easily be dismissed concerning the ex-',
#    'BoundingBox': {'Width': 0.3381541073322296,
#     'Height': 0.012135365977883339,
#     'Left': 0.5470730662345886,
#     'Top': 0.5070592164993286},
#    'Id': '187e704a-4997-4d2f-b84e-75094726fd60',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002985771745443344,
#    'height_diff_below': 0.0030029024928808212,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.18197051886743065,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.976345502503225,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88674926757812,
#    'Text': 'act ontological nature of the hybrid arrangement by',
#    'BoundingBox': {'Width': 0.3383806049823761,
#     'Height': 0.012129907496273518,
#     'Left': 0.547204315662384,
#     'Top': 0.5221974849700928},
#    'Id': '747fb7ec-5db4-4b21-b6ca-bb65fc73bb1d',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0030029024928808212,
#    'height_diff_below': 0.0028549982234835625,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.21236241018283553,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9829986131799267,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8985366821289,
#    'Text': "which the divinity's presence is made manifest. It is",
#    'BoundingBox': {'Width': 0.338032066822052,
#     'Height': 0.012063227593898773,
#     'Left': 0.5471490025520325,
#     'Top': 0.5371823906898499},
#    'Id': 'b8cc6f1a-d9a2-46a3-8953-f059377923f5',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0028549982234835625,
#    'height_diff_below': 0.002908863127231598,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.2424464073642819,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9801947590891125,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.8282470703125,
#    'Text': 'precisely the same sort of ontological uncertainty',
#    'BoundingBox': {'Width': 0.33800628781318665,
#     'Height': 0.01202689204365015,
#     'Left': 0.5473697781562805,
#     'Top': 0.5521544814109802},
#    'Id': '38163439-f99a-4472-88ba-c8e105077a48',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002908863127231598,
#    'height_diff_below': 0.0030075451359152794,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.2725046768975351,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9913860042964231,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6975326538086,
#    'Text': 'that one finds expressed in the field of robotics. And',
#    'BoundingBox': {'Width': 0.3379596471786499,
#     'Height': 0.011985193006694317,
#     'Left': 0.5473806858062744,
#     'Top': 0.5671889185905457},
#    'Id': 'fa2eed48-83f4-4ecc-ac49-25f8f18f6ad5',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0030075451359152794,
#    'height_diff_below': 0.0030609862878918648,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.3026881144308352,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9919389194889021,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.9035415649414,
#    'Text': 'this is also why robots both fascinate and worry the',
#    'BoundingBox': {'Width': 0.3379111588001251,
#     'Height': 0.012089177034795284,
#     'Left': 0.5474206209182739,
#     'Top': 0.5822350978851318},
#    'Id': 'e18f9094-33d7-4af4-9ea0-4d45cb6ae7d3',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0030609862878918648,
#    'height_diff_below': 0.003395454026758671,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.33289512566968915,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9939632538001604,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 0.7376667257035963},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.52567291259766,
#    'Text': 'general public.',
#    'BoundingBox': {'Width': 0.09428026527166367,
#     'Height': 0.01173343975096941,
#     'Left': 0.5468749403953552,
#     'Top': 0.5977197289466858},
#    'Id': 'a5e76928-75e7-4a6f-a0b9-2d2d16e3c15f',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.003395454026758671,
#    'height_diff_below': 0.018073233775794506,
#    'paragraph': 1,
#    'paragraph_std': 1,
#    'top_scl': 0.3639823814671904,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.9663023872037897,
#    'paragraph_std_scl': 0.25,
#    'text_cluster': 2,
#    'cluster_probability': 0.530909601957648},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.93135070800781,
#    'Text': '6.2 The moral and religious life of machines',
#    'BoundingBox': {'Width': 0.31428366899490356,
#     'Height': 0.012095442041754723,
#     'Left': 0.528290331363678,
#     'Top': 0.6275264024734497},
#    'Id': 'f1f85e6a-975e-400a-8c33-fa0e77cc06e1',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.018073233775794506,
#    'height_diff_below': 0.0184334609657526,
#    'paragraph': 1,
#    'paragraph_std': 2,
#    'top_scl': 0.42382285688540977,
#    'paragraph_scl': 0.3333333333333333,
#    'left_scl': 0.024237626634196374,
#    'paragraph_std_scl': 0.5,
#    'text_cluster': 0,
#    'cluster_probability': 0.1434444000150202},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92827606201172,
#    'Text': 'A pressing question is whether a real sense of moral re-',
#    'BoundingBox': {'Width': 0.3759782314300537,
#     'Height': 0.011910981498658657,
#     'Left': 0.5281528234481812,
#     'Top': 0.658055305480957},
#    'Id': 'f7bfe5d9-ca5b-4e12-b2af-499a831edef2',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0184334609657526,
#    'height_diff_below': 0.003034585155546665,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.48511329469040565,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.01726726953558355,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 0.8292029085360092},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84795379638672,
#    'Text': 'sponsibility can be developed in intelligent agents, or, more',
#    'BoundingBox': {'Width': 0.37622520327568054,
#     'Height': 0.012142231687903404,
#     'Left': 0.5284137725830078,
#     'Top': 0.6730008721351624},
#    'Id': 'a787c10a-6d38-4bf1-bbef-a7c6cceff271',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.003034585155546665,
#    'height_diff_below': 0.0028067324310541153,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.5151183139750729,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.03049493463213082,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.84844970703125,
#    'Text': 'fancifully perhaps, a proper religious sense. In human be-',
#    'BoundingBox': {'Width': 0.37574225664138794,
#     'Height': 0.012300929985940456,
#     'Left': 0.5284615159034729,
#     'Top': 0.6879498362541199},
#    'Id': '898ffb43-ff69-4ec8-8448-b5e21cf00004',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0028067324310541153,
#    'height_diff_below': 0.0029416466131806374,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.5451301540780985,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.03291507162215623,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.88512420654297,
#    'Text': 'ings, it may seem obvious that ethical decisions differ in',
#    'BoundingBox': {'Width': 0.37620705366134644,
#     'Height': 0.01185592357069254,
#     'Left': 0.528139054775238,
#     'Top': 0.703192412853241},
#    'Id': '5ba7a8ea-6929-40e8-8733-1bf0087ef783',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0029416466131806374,
#    'height_diff_below': 0.0032281046733260155,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.575731456483448,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.01656932740737105,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.75194549560547,
#    'Text': 'some significant respect from other kinds of decisions,',
#    'BoundingBox': {'Width': 0.37599822878837585,
#     'Height': 0.012068712152540684,
#     'Left': 0.5284170508384705,
#     'Top': 0.7182764410972595},
#    'Id': '0edfaccf-4dae-458a-9c1e-8238458ef448',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0032281046733260155,
#    'height_diff_below': 0.002985394559800625,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.6060144540320819,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.03066111132932292,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.87187957763672,
#    'Text': 'and that intellectual reasoning is subordinate to, or at least',
#    'BoundingBox': {'Width': 0.3768402636051178,
#     'Height': 0.012221094220876694,
#     'Left': 0.5278121829032898,
#     'Top': 0.7333305478096008},
#    'Id': '31797f24-f90e-4333-897d-7ac28e5c273a',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002985394559800625,
#    'height_diff_below': 0.0029193200170993805,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.6362373805137714,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.0,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.6059799194336,
#    'Text': 'strongly influenced by, emotional intelligence. As Liao',
#    'BoundingBox': {'Width': 0.3757619857788086,
#     'Height': 0.01217692531645298,
#     'Left': 0.5282239317893982,
#     'Top': 0.7484709620475769},
#    'Id': '15601a1d-0c5c-48d7-a3a3-c29dfd29d8a9',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0029193200170993805,
#    'height_diff_below': 0.0034014638513326645,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.6666335797144555,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.020871793167419384,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 0.8874329558154824},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.92679595947266,
#    'Text': '(2016) says:',
#    'BoundingBox': {'Width': 0.0738762766122818,
#     'Height': 0.011374508030712605,
#     'Left': 0.5288876891136169,
#     'Top': 0.7640493512153625},
#    'Id': 'f6e18ead-1b37-4afe-b891-6f68b584807a',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0034014638513326645,
#    'height_diff_below': 0.018130864016711712,
#    'paragraph': 2,
#    'paragraph_std': 3,
#    'top_scl': 0.6979090661659467,
#    'paragraph_scl': 0.6666666666666666,
#    'left_scl': 0.05451804225722512,
#    'paragraph_std_scl': 0.75,
#    'text_cluster': 0,
#    'cluster_probability': 0.5418980052398494},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.89524841308594,
#    'Text': 'Central area of intellectual inquiry across different',
#    'BoundingBox': {'Width': 0.3381929397583008,
#     'Height': 0.01220998540520668,
#     'Left': 0.547482430934906,
#     'Top': 0.7935547232627869},
#    'Id': '8baa7693-76e9-4f75-a733-33de904e82b9',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.018130864016711712,
#    'height_diff_below': 0.0028012655675411224,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.7571446426929261,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.9970964398908677,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.74400329589844,
#    'Text': 'disciplines involves understanding the nature, prac-',
#    'BoundingBox': {'Width': 0.3385259807109833,
#     'Height': 0.012518475763499737,
#     'Left': 0.5472660660743713,
#     'Top': 0.8085659742355347},
#    'Id': '1913ba7a-4b9f-4a5b-9595-0a330c22dc34',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0028012655675411224,
#    'height_diff_below': 0.0025945203378796577,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.7872815311325184,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.986128777876143,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 96.98355102539062,
#    'Text': 'tice, and reliability of moral judgments. For instance,',
#    'BoundingBox': {'Width': 0.3379009962081909,
#     'Height': 0.012284834869205952,
#     'Left': 0.5475397109985352,
#     'Top': 0.8236789703369141},
#    'Id': '83a44874-5d94-469e-941b-08e1cc9c789c',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0025945203378796577,
#    'height_diff_below': 0.002904633991420269,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.817622685132417,
#    'paragraph_scl': 1.0,
#    'left_scl': 1.0,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.86426544189453,
#    'Text': 'an issue of perennial interest concerns what moral',
#    'BoundingBox': {'Width': 0.33807218074798584,
#     'Height': 0.012069725431501865,
#     'Left': 0.5471169948577881,
#     'Top': 0.8388684391975403},
#    'Id': 'b4b0c5ad-be98-4f73-b9b4-c778eaefbb71',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002904633991420269,
#    'height_diff_below': 0.0031167035922408104,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.8481173673771146,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.9785722702456106,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.03174591064453,
#    'Text': 'judgments are and how moral judgments differ from',
#    'BoundingBox': {'Width': 0.33862510323524475,
#     'Height': 0.012088406831026077,
#     'Left': 0.5465965270996094,
#     'Top': 0.854054868221283},
#    'Id': '0c626b44-3f39-4579-a8fa-282b9a3bd5e1',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0031167035922408104,
#    'height_diff_below': 0.003013860434293747,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.8786059467843342,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.9521894535203792,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 0.9411431371824436},
#   {'BlockType': 'LINE',
#    'Confidnece': 93.83973693847656,
#    'Text': 'nonmoral judgments. Moral judgments such as "Tor-',
#    'BoundingBox': {'Width': 0.3379890024662018,
#     'Height': 0.012119278311729431,
#     'Left': 0.5473828911781311,
#     'Top': 0.8691571354866028},
#    'Id': '36f1a2d2-388a-4683-b2c5-1ae84a4b8438',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.003013860434293747,
#    'height_diff_below': 0.002848699688911438,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.9089255613578383,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.992050711085195,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.78987121582031,
#    'Text': 'ture is wrong" seem different from nonmoral judg-',
#    'BoundingBox': {'Width': 0.33758899569511414,
#     'Height': 0.012482848949730396,
#     'Left': 0.5475397109985352,
#     'Top': 0.8841251134872437},
#    'Id': 'ecf2178c-3b20-4f9e-b74e-d507e7ab005a',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.002848699688911438,
#    'height_diff_below': 0.0028634993359446526,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.9389755741109737,
#    'paragraph_scl': 1.0,
#    'left_scl': 1.0,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.10945892333984,
#    'Text': 'ments such as "Water is wet." But how do moral judg-',
#    'BoundingBox': {'Width': 0.3376505970954895,
#     'Height': 0.012195220217108727,
#     'Left': 0.5474132299423218,
#     'Top': 0.8994714617729187},
#    'Id': 'b7cdeb3a-3523-4ea2-a4ab-45240238c317',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0028634993359446526,
#    'height_diff_below': 0.0028548333793878555,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.9697852106349482,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.9935886008828518,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0},
#   {'BlockType': 'LINE',
#    'Confidnece': 99.68680572509766,
#    'Text': 'ments differ from nonmoral, but normative judg-',
#    'BoundingBox': {'Width': 0.33801883459091187,
#     'Height': 0.012343087233603,
#     'Left': 0.5473271012306213,
#     'Top': 0.9145215153694153},
#    'Id': 'bf5a935f-8197-4f11-a168-b4bd7bc34788',
#    'Quadrant': 'Q4',
#    'height_diff_above': 0.0028548333793878555,
#    'height_diff_below': 0,
#    'paragraph': 3,
#    'paragraph_std': 4,
#    'top_scl': 0.9999999999999999,
#    'paragraph_scl': 1.0,
#    'left_scl': 0.9892226858384241,
#    'paragraph_std_scl': 1.0,
#    'text_cluster': 1,
#    'cluster_probability': 1.0}],
#  'height_diff_mean': 0.0051191146646080345,
#  'height_diff_std': 0.005370177725166042}

# %%
df = pd.DataFrame(clustered_json)
df = df.join(pd.json_normalize(df["Blocks"].tolist()).add_prefix("Blocks.")).drop(["Blocks"], axis=1)
df['grouped_text'] = df.groupby('Blocks.paragraph')['Blocks.Text'].transform(lambda x: ' '.join(x))
df2 = df[['Blocks.paragraph', 'grouped_text']].drop_duplicates()
df3 = df2.sort_values(by='Blocks.paragraph')
df3
# Out:
#     Blocks.paragraph                                       grouped_text
# 0                  0  gods, asking whether the similarities are not ...
# 2                  1  But it is also true that where interaction is ...
# 13                 2  A pressing question is whether a real sense of...
# 21                 3  Central area of intellectual inquiry across di...
